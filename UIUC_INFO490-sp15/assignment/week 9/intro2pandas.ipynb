# %% [markdown]
# <DIV ALIGN=CENTER>
#
# # Introduction to Pandas
# ## Professor Robert J. Brunner
#
# </DIV>
# -----
# -----

# %% [markdown]
# ## Introduction
#
# One of the early criticisms of many in the data science arena of the
# Python language was the lack of useful data structures for performing
# data analysis tasks. This stemmed in part from comparisons between the R
# language and Python, since R has a built-in _DataFrame_ object that
# greatly simplified many data analysis tasks. This deficiency was
# addressed in 2008 by Wes McKinney with the creation of [Pandas][1] (the
# name was originally an abbreviation of Panel datas). To quote the Pandas
# documentation:
#
# >Python has long been great for data munging and preparation, but less
# >so for data analysis and modeling. pandas helps fill this gap, enabling
# >you to carry out your entire data analysis workflow in Python without
# >having to switch to a more domain specific language like R.
#
# Pandas introduces several new data structures like the `Series`,
# `DataFrame`, and `Panel` that build on top of existing
# tools like `numpy` to speed-up data analysis tasks. Pandas also provides
# efficient mechanisms for moving data between in memory representations
# and different data formats including CSV and text files, JSON files, SQL
# databases, HDF5 format files, and even Excel spreadsheets. Pandas also
# provides support for dealing with missing or incomplete data and
# aggregating or grouping data.
#
# -----
# [1]: http://pandas.pydata.org

# %% [markdown]
# ## Brief introduction to Pandas
#
# Before using Pandas, we must first import the Pandas library:
#
#     import pandas as pd
#
# Second, we simply create and use the appropriate Pandas data structure.
# The two most important data structures for typical data science tasks
# are the `Series` and the `DataFrame`:
#
# 1. `Series`: a one-dimensional labeled array that can hold any data type
# such as integers, floating-point numbers, strings, or Python objects. A
# `Series` has both a data column and a label column called the _index_.
#
# 2. `DataFrame`: a two-dimensional labeled data structure with columns
# that can be hold different data types, similar to a spreadsheet or
# relational database table.
#
# Pandas also provides a date/time data structure sometimes refereed to as
# a `TimeSeries` and a three-dimensional data structure known as a
# `Panel`.
#
# ### `Series`
#
# A `Series` is useful to hold data that should be accesible by using a
# specific label. You create a `Series` by passing in an appropriate data
# set along with an optional index:
#
#     values = pd.Series(data, index=idx)
#
# The index varies depending on the type of data passed in to create the
# `Series:
#
# - if data is a NumPy array, the index should be the same length as the
# data array. If no index is provided one will be created that enables
# integer access that mirrors a traditional NumPy array (i.e., zero
# indexed).
#
# - if data is a Python dictionary, `idx` can contain specific labels to
# indicate which values in the dictionary should be used to create the
# `Series`. If no index is specified, an index is created from the sorted
# dictionary keys.
#
# - if data is a scalar value, an inde must be supplied. In this case, the
# scalar value will be repeated to ensure that each label in the index has
# a value in the `Series`.
#
# These different options are demonstrated in the following code cells.
#
# -----
# [df]: http://pandas.pydata.org/pandas-docs/stable/dsintro.html#dataframe

# %%
import pandas as pd
import numpy as np

# We label the random values
s1 = pd.Series(np.random.rand(6), index=['q', 'w', 'e', 'r', 't', 'y'])

print(s1)
# Out:
# q    0.776339
# w    0.785962
# e    0.924433
# r    0.404584
# t    0.684645
# y    0.084985
# dtype: float64

# %%
d = {'q': 11, 'w': 21, 'e': 31, 'r': 41}

# We pick out the q, w, and r keys, but have an undefined y key.
s2 = pd.Series(d, index = ['q', 'w', 'r', 'y'])

print(s2)
# Out:
# q    11
# w    21
# r    41
# y   NaN
# dtype: float64

# %%
pd.Series(d)
# Out:
# e    31
# q    11
# r    41
# w    21
# dtype: int64

# %%
# We create a Series from an integer constant with explicit labels
s3 = pd.Series(42, index = ['q', 'w', 'e', 'r', 't', 'y'])

print(s3)

print('\nThe "e" value is ', s3['e'])
# Out:
# q    42
# w    42
# e    42
# r    42
# t    42
# y    42
# dtype: int64
#
# The "e" value is  42

# %%
# We can slice like NumPy arrays

print(s1[:-2])

# We can also perform vectorized operations
print('\nSum Series:')
print(s1 + s3)
print('\nSeries operations:')
print(s2 * 5 - 1.2)
# Out:
# q    0.776339
# w    0.785962
# e    0.924433
# r    0.404584
# dtype: float64
#
# Sum Series:
# q    42.776339
# w    42.785962
# e    42.924433
# r    42.404584
# t    42.684645
# y    42.084985
# dtype: float64
#
# Series operations:
# q     53.8
# w    103.8
# r    203.8
# y      NaN
# dtype: float64

# %% [markdown]
# -----
#
# ### `DataFrame`
#
# The second major data structure that Pandas provdis is he `DataFrame`,
# which is a two-dimensional array, where each column is effectively a
# `Series` with a shared index. A DataFrame is a very powerful data
# structure and provides a nice mapping for a number of different data
# formats (and storage mechanisms). For example, you can easily read data
# from a CSV file, a fixed width format text file, a JSOPN file, an HTML
# file, and HDF file, and a relational database into a Pandas `DataFrame`.
# This is demonstrated in the next set of code cells, where we extract
# data from files we created in the [Introduction to Data
# Formats][df] Notebook.
#
# -----
# [df]: dataformats.ipynb

# %%
# Read data from CSV file, and display subset

dfa = pd.read_csv('data.csv', delimiter='|', index_col='iata')

# We can grab the first five rows, and only extract the 'airport' column
print(dfa[['airport', 'city', 'state']].head(5))
# Out:
#                    airport              city state
# iata
# 00M               Thigpen        Bay Springs    MS
# 00R   Livingston Municipal        Livingston    TX
# 00V            Meadow Lake  Colorado Springs    CO
# 01G           Perry-Warsaw             Perry    NY
# 01J       Hilliard Airpark          Hilliard    FL
#
# [5 rows x 3 columns]

# %%
# Read data from our JSON file
dfb = pd.read_json('data.json')

# Grab the last five rows
print(dfb[[0, 1, 2, 3, 5, 6]].tail(5))
# Out:
#         0                          1            2   3            5  \
# 3372  ZEF            Elkin Municipal        Elkin  NC  36.28002361
# 3373  ZER  Schuylkill Cty/Joe Zerbey   Pottsville  PA  40.70644889
# 3374  ZPH      Zephyrhills Municipal  Zephyrhills  FL  28.22806472
# 3375  ZUN                 Black Rock         Zuni  NM  35.08322694
# 3376  ZZV       Zanesville Municipal   Zanesville  OH  39.94445833
#
#                  6
# 3372  -80.78606861
# 3373  -76.37314667
# 3374  -82.15591639
# 3375  -108.7917769
# 3376  -81.89210528
#
# [5 rows x 6 columns]

# %%
dfb
# Out:
#        0                           1                   2      3        4  \
# 0   iata                     airport                city  state  country
# 1    00M                    Thigpen          Bay Springs     MS      USA
# 2    00R        Livingston Municipal          Livingston     TX      USA
# 3    00V                 Meadow Lake    Colorado Springs     CO      USA
# 4    01G                Perry-Warsaw               Perry     NY      USA
# 5    01J            Hilliard Airpark            Hilliard     FL      USA
# 6    01M           Tishomingo County             Belmont     MS      USA
# 7    02A                 Gragg-Wade              Clanton     AL      USA
# 8    02C                     Capitol          Brookfield     WI      USA
# 9    02G           Columbiana County      East Liverpool     OH      USA
# 10   03D            Memphis Memorial             Memphis     MO      USA
# 11   04M              Calhoun County           Pittsboro     MS      USA
# 12   04Y            Hawley Municipal              Hawley     MN      USA
# 13   05C      Griffith-Merrillville             Griffith     IN      USA
# 14   05F    Gatesville - City/County          Gatesville     TX      USA
# 15   05U                      Eureka              Eureka     NV      USA
# 16   06A            Moton  Municipal            Tuskegee     AL      USA
# 17   06C                  Schaumburg  Chicago/Schaumburg     IL      USA
# 18   06D             Rolla Municipal               Rolla     ND      USA
# 19   06M            Eupora Municipal              Eupora     MS      USA
# 20   06N                    Randall           Middletown     NY      USA
# 21   06U             Jackpot/Hayden              Jackpot     NV      USA
# 22   07C               Dekalb County              Auburn     IN      USA
# 23   07F        Gladewater Municipal          Gladewater     TX      USA
# 24   07G               Fitch H Beach           Charlotte     MI      USA
# 25   07K      Central City Municipal        Central City     NE      USA
# 26   08A          Wetumpka Municipal            Wetumpka     AL      USA
# 27   08D           Stanley Municipal             Stanley     ND      USA
# 28   08K               Harvard State             Harvard     NE      USA
# 29   08M       Carthage-Leake County            Carthage     MS      USA
# 30   09A       Butler-Choctaw County              Butler     AL      USA
# 31   09J               Jekyll Island       Jekyll Island     GA      USA
# 32   09K           Sargent Municipal             Sargent     NE      USA
# 33   09M        Charleston Municipal          Charleston     MS      USA
# 34   09W        South Capitol Street          Washington     DC      USA
# 35   0A3        Smithville Municipal          Smithville     TN      USA
# 36   0A8                 Bibb County         Centreville     AL      USA
# 37   0A9      Elizabethton Municipal        Elizabethton     TN      USA
# 38   0AK               Pilot Station       Pilot Station     AK      USA
# 39   0B1                  Col. Dyke               Bethel     ME      USA
# 40   0B4        Hartington Municipal          Hartington     NE      USA
# 41   0B5               Turners Falls            Montague     MA      USA
# 42   0B7           Warren-Sugar Bush              Warren     VT      USA
# 43   0B8                  Elizabeth       Fishers Island     NY      USA
# 44   0C0                        Dacy     Chicago/Harvard     IL      USA
# 45   0C4            Pender Municipal              Pender     NE      USA
# 46   0D1       South Haven Municipal         South Haven     MI      USA
# 47   0D8        Gettysburg Municipal          Gettysburg     SD      USA
# 48   0E0                    Moriarty            Moriarty     NM      USA
# 49   0E8                  Crownpoint          Crownpoint     NM      USA
# 50   0F2             Bowie Municipal               Bowie     TX      USA
# 51   0F4         Loup City Municipal           Loup City     NE      USA
# 52   0F7  Fountainhead Lodge Airpark             Eufaula     OK      USA
# 53   0F8   William R Pogue Municipal        Sand Springs     OK      USA
# 54   0F9          Tishomingo Airpark          Tishomingo     OK      USA
# 55   0G0      North Buffalo Suburban            Lockport     NY      USA
# 56   0G3          Tecumseh Municipal            Tecumseh     NE      USA
# 57   0G6             Williams County               Bryan     OH      USA
# 58   0G7       Finger Lakes Regional        Seneca Falls     NY      USA
# 59   0H1             Trego Wakeeney             Wakeeney     KS      USA
#      ...                         ...                 ...    ...      ...
#
#               5             6
# 0           lat          long
# 1   31.95376472  -89.23450472
# 2   30.68586111  -95.01792778
# 3   38.94574889  -104.5698933
# 4   42.74134667  -78.05208056
# 5    30.6880125  -81.90594389
# 6   34.49166667  -88.20111111
# 7   32.85048667  -86.61145333
# 8      43.08751  -88.17786917
# 9   40.67331278  -80.64140639
# 10  40.44725889  -92.22696056
# 11  33.93011222  -89.34285194
# 12  46.88384889  -96.35089861
# 13  41.51961917  -87.40109333
# 14  31.42127556  -97.79696778
# 15  39.60416667  -116.0050597
# 16  32.46047167  -85.68003611
# 17  41.98934083  -88.10124278
# 18  48.88434111  -99.62087694
# 19  33.53456583  -89.31256917
# 20  41.43156583  -74.39191722
# 21  41.97602222  -114.6580911
# 22  41.30716667  -85.06433333
# 23  32.52883861  -94.97174556
# 24  42.57450861  -84.81143139
# 25  41.11668056  -98.05033639
# 26  32.52943944  -86.32822139
# 27  48.30079861  -102.4063514
# 28  40.65138528  -98.07978667
# 29  32.76124611  -89.53007139
# 30  32.11931306   -88.1274625
# 31  31.07447222  -81.42777778
# 32  41.63695083  -99.34038139
# 33  33.99150222    -90.078145
# 34  38.86872333  -77.00747583
# 35  35.98531194  -85.80931806
# 36  32.93679056  -87.08888306
# 37  36.37094306  -82.17374111
# 38  61.93396417  -162.8929358
# 39  44.42506444  -70.80784778
# 40  42.60355556  -97.25263889
# 41  42.59136361  -72.52275472
# 42  44.11672722  -72.82705806
# 43  41.25130806  -72.03161139
# 44  42.40418556  -88.63343222
# 45  42.11388722  -96.72892556
# 46  42.35083333  -86.25613889
# 47  44.98730556      -99.9535
# 48  34.98560639  -106.0094661
# 49  35.71765889  -108.2015961
# 50  33.60166667     -97.77556
# 51  41.29028694  -98.99064278
# 52  35.38898833  -95.60165111
# 53     36.17528  -96.15181028
# 54  34.19592833  -96.67555694
# 55  43.10318389  -78.70334583
# 56  40.39944417  -96.17139694
# 57  41.46736111  -84.50655556
# 58  42.88062278  -76.78162028
# 59   39.0044525  -99.89289917
#             ...           ...
#
# [3377 rows x 7 columns]

# %% [markdown]
# -----
#
# In the previous code cells, we read data first from a delimiter
# separated value file and second from a JSON file into a Pandas
# `DataFrame`. In each code cell, we display data contained in the new
# DataFrame, first by using the `head` method to display the first few
# rows, and second by using the `tail` method to display the last few
# lines. For the delimiter separated value file, we explicitly specified
# the delimiter, which is a vertical bar `|`, the default is to assume a
# comma as the delimiter. We also explicitly specify the `iata` column
# should be used as the index column, which is how we can refer to rows in
# the array.
#
# We also explicitly select columns for display in both code cells. In the
# first code cell, we explicitly name the columns, passing in a list of
# the names to the DataFrame. Alternatively, in the second code cell, we
# pass in a list of the column ids, which we must do since we did not
# create named columns when reading data from the JSON file. The list of
# integers can be used even if the columns of the array have been assigned
# names.
#
# Pandas includes a tremendous amount of functionality, especially for
# the `DataFrame`, to learn more, view the [detailed documentation][pdd].
# Several useful functions are demonstrated below, however, including
# information summaries, slicing, and column operations on DataFrames.
#
# -----
#
# [pdd]: http://pandas.pydata.org/pandas-docs/stable/dsintro.html#dataframe

# %%
dfa
# Out:
#                          airport                city state country        lat  \
# iata
# 00M                     Thigpen          Bay Springs    MS     USA  31.953765
# 00R         Livingston Municipal          Livingston    TX     USA  30.685861
# 00V                  Meadow Lake    Colorado Springs    CO     USA  38.945749
# 01G                 Perry-Warsaw               Perry    NY     USA  42.741347
# 01J             Hilliard Airpark            Hilliard    FL     USA  30.688012
# 01M            Tishomingo County             Belmont    MS     USA  34.491667
# 02A                  Gragg-Wade              Clanton    AL     USA  32.850487
# 02C                      Capitol          Brookfield    WI     USA  43.087510
# 02G            Columbiana County      East Liverpool    OH     USA  40.673313
# 03D             Memphis Memorial             Memphis    MO     USA  40.447259
# 04M               Calhoun County           Pittsboro    MS     USA  33.930112
# 04Y             Hawley Municipal              Hawley    MN     USA  46.883849
# 05C       Griffith-Merrillville             Griffith    IN     USA  41.519619
# 05F     Gatesville - City/County          Gatesville    TX     USA  31.421276
# 05U                       Eureka              Eureka    NV     USA  39.604167
# 06A             Moton  Municipal            Tuskegee    AL     USA  32.460472
# 06C                   Schaumburg  Chicago/Schaumburg    IL     USA  41.989341
# 06D              Rolla Municipal               Rolla    ND     USA  48.884341
# 06M             Eupora Municipal              Eupora    MS     USA  33.534566
# 06N                     Randall           Middletown    NY     USA  41.431566
# 06U              Jackpot/Hayden              Jackpot    NV     USA  41.976022
# 07C                Dekalb County              Auburn    IN     USA  41.307167
# 07F         Gladewater Municipal          Gladewater    TX     USA  32.528839
# 07G                Fitch H Beach           Charlotte    MI     USA  42.574509
# 07K       Central City Municipal        Central City    NE     USA  41.116681
# 08A           Wetumpka Municipal            Wetumpka    AL     USA  32.529439
# 08D            Stanley Municipal             Stanley    ND     USA  48.300799
# 08K                Harvard State             Harvard    NE     USA  40.651385
# 08M        Carthage-Leake County            Carthage    MS     USA  32.761246
# 09A        Butler-Choctaw County              Butler    AL     USA  32.119313
# 09J                Jekyll Island       Jekyll Island    GA     USA  31.074472
# 09K            Sargent Municipal             Sargent    NE     USA  41.636951
# 09M         Charleston Municipal          Charleston    MS     USA  33.991502
# 09W         South Capitol Street          Washington    DC     USA  38.868723
# 0A3         Smithville Municipal          Smithville    TN     USA  35.985312
# 0A8                  Bibb County         Centreville    AL     USA  32.936791
# 0A9       Elizabethton Municipal        Elizabethton    TN     USA  36.370943
# 0AK                Pilot Station       Pilot Station    AK     USA  61.933964
# 0B1                   Col. Dyke               Bethel    ME     USA  44.425064
# 0B4         Hartington Municipal          Hartington    NE     USA  42.603556
# 0B5                Turners Falls            Montague    MA     USA  42.591364
# 0B7            Warren-Sugar Bush              Warren    VT     USA  44.116727
# 0B8                   Elizabeth       Fishers Island    NY     USA  41.251308
# 0C0                         Dacy     Chicago/Harvard    IL     USA  42.404186
# 0C4             Pender Municipal              Pender    NE     USA  42.113887
# 0D1        South Haven Municipal         South Haven    MI     USA  42.350833
# 0D8         Gettysburg Municipal          Gettysburg    SD     USA  44.987306
# 0E0                     Moriarty            Moriarty    NM     USA  34.985606
# 0E8                   Crownpoint          Crownpoint    NM     USA  35.717659
# 0F2              Bowie Municipal               Bowie    TX     USA  33.601667
# 0F4          Loup City Municipal           Loup City    NE     USA  41.290287
# 0F7   Fountainhead Lodge Airpark             Eufaula    OK     USA  35.388988
# 0F8    William R Pogue Municipal        Sand Springs    OK     USA  36.175280
# 0F9           Tishomingo Airpark          Tishomingo    OK     USA  34.195928
# 0G0       North Buffalo Suburban            Lockport    NY     USA  43.103184
# 0G3           Tecumseh Municipal            Tecumseh    NE     USA  40.399444
# 0G6              Williams County               Bryan    OH     USA  41.467361
# 0G7        Finger Lakes Regional        Seneca Falls    NY     USA  42.880623
# 0H1              Trego Wakeeney             Wakeeney    KS     USA  39.004452
# 0I8    Cynthiana-Harrison County           Cynthiana    KY     USA  38.366742
#                              ...                 ...   ...     ...        ...
#
#             long
# iata
# 00M   -89.234505
# 00R   -95.017928
# 00V  -104.569893
# 01G   -78.052081
# 01J   -81.905944
# 01M   -88.201111
# 02A   -86.611453
# 02C   -88.177869
# 02G   -80.641406
# 03D   -92.226961
# 04M   -89.342852
# 04Y   -96.350899
# 05C   -87.401093
# 05F   -97.796968
# 05U  -116.005060
# 06A   -85.680036
# 06C   -88.101243
# 06D   -99.620877
# 06M   -89.312569
# 06N   -74.391917
# 06U  -114.658091
# 07C   -85.064333
# 07F   -94.971746
# 07G   -84.811431
# 07K   -98.050336
# 08A   -86.328221
# 08D  -102.406351
# 08K   -98.079787
# 08M   -89.530071
# 09A   -88.127462
# 09J   -81.427778
# 09K   -99.340381
# 09M   -90.078145
# 09W   -77.007476
# 0A3   -85.809318
# 0A8   -87.088883
# 0A9   -82.173741
# 0AK  -162.892936
# 0B1   -70.807848
# 0B4   -97.252639
# 0B5   -72.522755
# 0B7   -72.827058
# 0B8   -72.031611
# 0C0   -88.633432
# 0C4   -96.728926
# 0D1   -86.256139
# 0D8   -99.953500
# 0E0  -106.009466
# 0E8  -108.201596
# 0F2   -97.775560
# 0F4   -98.990643
# 0F7   -95.601651
# 0F8   -96.151810
# 0F9   -96.675557
# 0G0   -78.703346
# 0G3   -96.171397
# 0G6   -84.506556
# 0G7   -76.781620
# 0H1   -99.892899
# 0I8   -84.284101
#              ...
#
# [3376 rows x 6 columns]

# %%
# Lets look at the datatypes of each column
dfa.dtypes
# Out:
# airport     object
# city        object
# state       object
# country     object
# lat        float64
# long       float64
# dtype: object

# %%
# We can get a summary of numerical information in the dataframe

dfa.describe()
# Out:
#                lat         long
# count  3376.000000  3376.000000
# mean     40.036524   -98.621205
# std       8.329559    22.869458
# min       7.367222  -176.646031
# 25%      34.688427  -108.761121
# 50%      39.434449   -93.599425
# 75%      43.372612   -84.137519
# max      71.285448   145.621384
#
# [8 rows x 2 columns]

# %%
# Notice the JSON data did not automatically specify data types
dfb.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# 6    object
# dtype: object

# %%
# This affects the output of the describe method, dfb has no numerical data types.

dfb.describe()
# Out:
#            0          1     2     3     4            5             6
# count   3377       3377  3377  3377  3377         3377          3377
# unique  3377       3246  2677    58     6         3376          3376
# top      4Z7  Municipal    NA    AK   USA  41.61033333  -88.91561611
# freq       1          5    12   263  3372            2             2
#
# [4 rows x 7 columns]

# %%
# We can slice out rows using the indicated index for dfa

print(dfa.loc[['00V', '11R', '12C']])
# Out:
#                 airport              city state country        lat        long
# 00V         Meadow Lake  Colorado Springs    CO     USA  38.945749 -104.569893
# 11R   Brenham Municipal           Brenham    TX     USA  30.219000  -96.374278
# 12C  Rochelle Municipal          Rochelle    IL     USA  41.893001  -89.078290
#
# [3 rows x 6 columns]

# %%
# We can slice out rows using the row index for dfb
print(dfb[100:105])
# Out:
#        0                   1         2   3    4            5             6
# 100  11J        Early County   Blakely  GA  USA  31.39698611  -84.89525694
# 101  11R   Brenham Municipal   Brenham  TX  USA       30.219  -96.37427778
# 102  12C  Rochelle Municipal  Rochelle  IL  USA  41.89300139     -89.07829
# 103  12D     Tower Municipal     Tower  MN  USA  47.81833333  -92.29166667
# 104  12J   Brewton Municipal   Brewton  AL  USA  31.05126306  -87.06796833
#
# [5 rows x 7 columns]

# %%
# We can also select rows based on boolean tests on columns
print(dfa[(dfa.lat > 48) & (dfa.long < -170)])
# Out:
#        airport      city state country        lat        long
# iata
# ADK       Adak      Adak    AK     USA  51.877964 -176.646031
# AKA       Atka      Atka    AK     USA  52.220348 -174.206350
# GAM    Gambell   Gambell    AK     USA  63.766766 -171.732824
# SNP   St. Paul  St. Paul    AK     USA  57.167333 -170.220444
# SVA   Savoonga  Savoonga    AK     USA  63.686394 -170.492636
#
# [5 rows x 6 columns]

# %% [markdown]
# -----
#
# We can also perform numerical operations on a `DataFrame`, just as was the
# case with NumPy arrays. To demonstrate this, we create a numerical
# DataFrame, apply different operations, and view the results.
#
# -----

# %%
df = pd.DataFrame(np.random.randn(5, 6))

print(df)
# Out:
#           0         1         2         3         4         5
# 0  0.626687 -1.547130  1.443410 -0.694652  0.725901  1.214665
# 1  1.762834  0.749440 -0.739589  0.040311 -0.386152  1.284557
# 2  1.508848 -0.576782  0.697576  1.000593 -1.062882  1.303139
# 3  0.347360 -0.316864 -0.218139  0.985198 -0.101444 -1.239659
# 4 -0.210160  0.484756  0.785770  1.017115 -0.089645  0.093880
#
# [5 rows x 6 columns]

# %%
# We can incorporate operate with basic scalar values

df + 2.5
# Out:
#           0         1         2         3         4         5
# 0  3.126687  0.952870  3.943410  1.805348  3.225901  3.714665
# 1  4.262834  3.249440  1.760411  2.540311  2.113848  3.784557
# 2  4.008848  1.923218  3.197576  3.500593  1.437118  3.803139
# 3  2.847360  2.183136  2.281861  3.485198  2.398556  1.260341
# 4  2.289840  2.984756  3.285770  3.517115  2.410355  2.593880
#
# [5 rows x 6 columns]

# %%
# And perform more complex scalar operations

-1.0 * df + 3.5
# Out:
#           0         1         2         3         4         5
# 0  2.873313  5.047130  2.056590  4.194652  2.774099  2.285335
# 1  1.737166  2.750560  4.239589  3.459689  3.886152  2.215443
# 2  1.991152  4.076782  2.802424  2.499407  4.562882  2.196861
# 3  3.152640  3.816864  3.718139  2.514802  3.601444  4.739659
# 4  3.710160  3.015244  2.714230  2.482885  3.589645  3.406120
#
# [5 rows x 6 columns]

# %%
# We can also apply vectorized functions

np.sin(df)
# Out:
#           0         1         2         3         4         5
# 0  0.586465 -0.999720  0.991897 -0.640118  0.663809  0.937253
# 1  0.981617  0.681229 -0.673984  0.040300 -0.376627  0.959312
# 2  0.998082 -0.545329  0.642362  0.841791 -0.873761  0.964393
# 3  0.340417 -0.311589 -0.216413  0.833382 -0.101270 -0.945673
# 4 -0.208616  0.465993  0.707369  0.850594 -0.089525  0.093742
#
# [5 rows x 6 columns]

# %%
# We can tranpose the dataframe

df.T
# Out:
#           0         1         2         3         4
# 0  0.626687  1.762834  1.508848  0.347360 -0.210160
# 1 -1.547130  0.749440 -0.576782 -0.316864  0.484756
# 2  1.443410 -0.739589  0.697576 -0.218139  0.785770
# 3 -0.694652  0.040311  1.000593  0.985198  1.017115
# 4  0.725901 -0.386152 -1.062882 -0.101444 -0.089645
# 5  1.214665  1.284557  1.303139 -1.239659  0.093880
#
# [6 rows x 5 columns]

# %% [markdown]
# -----
#
# The above description merely scratchs the surface of what you can do
# with a Pandas `Series` or a `DataFrame`. The best way to learn how to
# effectively use these data structures is to just do it!
#
# We now will change gears and explore how to use Pandas with a relational
# database.
#
# -----

# %% [markdown]
# ### Additional References
#
# 1. [Pandas Documentation][pdd]
# 2. A slightly dated Pandas [tutorial][pdt]
# -----
#
# [pdd]: http://pandas.pydata.org/pandas-docs/stable/index.html
# [pdt]: http://www.gregreda.com/2013/10/26/intro-to-pandas-data-structures/
