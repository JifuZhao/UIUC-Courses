# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from RNN import RNN

# %matplotlib inline

# load the MNIST dataset
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("data/", one_hot=True)
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# # Part I. Vinalla RNN with Sequence of Pixels

# %%
# define parameters
category = 'basicRNN'
learning_rate = 0.001
max_iters = 2000
batch_size = 128
n_input = 1
n_steps = 784
n_hidden = 100
n_classes = 10
regression = 'logistic'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='C', frequence=1, size=500, show_frequence=100)

# get training accuracy and testing accuracy
model1_train_acc, model1_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model1_train_acc)+1), model1_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model1_cv_acc)+1), model1_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.10400, Validation Accuracy= 0.11600
# Iteration 200, Training Accuracy= 0.08000, Validation Accuracy= 0.09600
# Iteration 300, Training Accuracy= 0.08000, Validation Accuracy= 0.10400
# Iteration 400, Training Accuracy= 0.09400, Validation Accuracy= 0.09000
# Iteration 500, Training Accuracy= 0.11600, Validation Accuracy= 0.11400
# Iteration 600, Training Accuracy= 0.10600, Validation Accuracy= 0.09800
# Iteration 700, Training Accuracy= 0.11600, Validation Accuracy= 0.12000
# Iteration 800, Training Accuracy= 0.10800, Validation Accuracy= 0.06600
# Iteration 900, Training Accuracy= 0.11800, Validation Accuracy= 0.11000
# Iteration 1000, Training Accuracy= 0.11600, Validation Accuracy= 0.09800
# Iteration 1100, Training Accuracy= 0.12200, Validation Accuracy= 0.10400
# Iteration 1200, Training Accuracy= 0.08600, Validation Accuracy= 0.09200
# Iteration 1300, Training Accuracy= 0.10400, Validation Accuracy= 0.10600
# Iteration 1400, Training Accuracy= 0.08800, Validation Accuracy= 0.10200
# Iteration 1500, Training Accuracy= 0.09800, Validation Accuracy= 0.09200
# Iteration 1600, Training Accuracy= 0.10200, Validation Accuracy= 0.10800
# Iteration 1700, Training Accuracy= 0.10200, Validation Accuracy= 0.10800
# Iteration 1800, Training Accuracy= 0.10800, Validation Accuracy= 0.08000
# Iteration 1900, Training Accuracy= 0.08600, Validation Accuracy= 0.10600
# Iteration 2000, Training Accuracy= 0.11400, Validation Accuracy= 0.09400
#
#
# Training is finished in 10828.0 s !
# Final Training Accuracy: 0.09898
# Final Testing Accuracy:  0.09800

# %% [markdown]
# # Part II. LSTM with Sequence of Pixels

# %%
# define parameters
category = 'LSTM'
learning_rate = 0.001
max_iters = 1000
batch_size = 128
n_input = 1
n_steps = 784
n_hidden = 100
n_classes = 10
regression = 'logistic'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='C', frequence=1, size=500, show_frequence=50)

# get training accuracy and testing accuracy
model2_train_acc, model2_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model2_train_acc)+1), model2_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model2_cv_acc)+1), model2_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 50, Training Accuracy= 0.17600, Validation Accuracy= 0.16200
# Iteration 100, Training Accuracy= 0.24000, Validation Accuracy= 0.23200
# Iteration 150, Training Accuracy= 0.34400, Validation Accuracy= 0.30800
# Iteration 200, Training Accuracy= 0.07000, Validation Accuracy= 0.11800
# Iteration 250, Training Accuracy= 0.12800, Validation Accuracy= 0.12400
# Iteration 300, Training Accuracy= 0.10600, Validation Accuracy= 0.11200
# Iteration 350, Training Accuracy= 0.06600, Validation Accuracy= 0.10600
# Iteration 400, Training Accuracy= 0.07800, Validation Accuracy= 0.08000
# Iteration 450, Training Accuracy= 0.11200, Validation Accuracy= 0.10000
# Iteration 500, Training Accuracy= 0.10000, Validation Accuracy= 0.06800
# Iteration 550, Training Accuracy= 0.15600, Validation Accuracy= 0.15200
# Iteration 600, Training Accuracy= 0.10800, Validation Accuracy= 0.11000
# Iteration 650, Training Accuracy= 0.11600, Validation Accuracy= 0.11000
# Iteration 700, Training Accuracy= 0.13000, Validation Accuracy= 0.11000
# Iteration 750, Training Accuracy= 0.05200, Validation Accuracy= 0.04800
# Iteration 800, Training Accuracy= 0.09200, Validation Accuracy= 0.08800
# Iteration 850, Training Accuracy= 0.06400, Validation Accuracy= 0.11600
# Iteration 900, Training Accuracy= 0.07200, Validation Accuracy= 0.08400
# Iteration 950, Training Accuracy= 0.09400, Validation Accuracy= 0.12600
# Iteration 1000, Training Accuracy= 0.11800, Validation Accuracy= 0.09200
#
#
# Training is finished in 10940.0 s !
# Final Training Accuracy: 0.09436
# Final Testing Accuracy:  0.09360

# %% [markdown]
# # Part III. Vinalla RNN with Sequence of Columns

# %%
# define parameters
# 28 steps, inputs is 28 column vector
category = 'basicRNN'
learning_rate = 0.001
max_iters = 2000
batch_size = 128
n_input = 28
n_steps = 28
n_hidden = 100
n_classes = 10
regression = 'logistic'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='F', frequence=1, size=500, show_frequence=100)

# get training accuracy and testing accuracy
model3_train_acc, model3_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model3_train_acc)+1), model3_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model3_cv_acc)+1), model3_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.63400, Validation Accuracy= 0.64200
# Iteration 200, Training Accuracy= 0.69400, Validation Accuracy= 0.72000
# Iteration 300, Training Accuracy= 0.75000, Validation Accuracy= 0.78600
# Iteration 400, Training Accuracy= 0.86800, Validation Accuracy= 0.87600
# Iteration 500, Training Accuracy= 0.84800, Validation Accuracy= 0.91600
# Iteration 600, Training Accuracy= 0.85800, Validation Accuracy= 0.85800
# Iteration 700, Training Accuracy= 0.89800, Validation Accuracy= 0.90600
# Iteration 800, Training Accuracy= 0.87800, Validation Accuracy= 0.90000
# Iteration 900, Training Accuracy= 0.90800, Validation Accuracy= 0.89600
# Iteration 1000, Training Accuracy= 0.90400, Validation Accuracy= 0.92000
# Iteration 1100, Training Accuracy= 0.91200, Validation Accuracy= 0.91600
# Iteration 1200, Training Accuracy= 0.93400, Validation Accuracy= 0.91800
# Iteration 1300, Training Accuracy= 0.92200, Validation Accuracy= 0.91400
# Iteration 1400, Training Accuracy= 0.89800, Validation Accuracy= 0.92000
# Iteration 1500, Training Accuracy= 0.88400, Validation Accuracy= 0.89800
# Iteration 1600, Training Accuracy= 0.90200, Validation Accuracy= 0.92600
# Iteration 1700, Training Accuracy= 0.92000, Validation Accuracy= 0.93000
# Iteration 1800, Training Accuracy= 0.94600, Validation Accuracy= 0.94000
# Iteration 1900, Training Accuracy= 0.94400, Validation Accuracy= 0.93400
# Iteration 2000, Training Accuracy= 0.89600, Validation Accuracy= 0.92000
#
#
# Training is finished in 399.0 s !
# Final Training Accuracy: 0.92376
# Final Testing Accuracy:  0.92420

# %% [markdown]
# # Part IV. LSTM with Sequence of Columns

# %%
# define parameters 
# 28 steps, inputs is 28 column vector
category = 'LSTM'
learning_rate = 0.001
max_iters = 2000
batch_size = 128
n_input = 28
n_steps = 28
n_hidden = 100
n_classes = 10
regression = 'logistic'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='F', frequence=1, size=500, show_frequence=100)

# get training accuracy and testing accuracy
model4_train_acc, model4_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model4_train_acc)+1), model4_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model4_cv_acc)+1), model4_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.63200, Validation Accuracy= 0.64800
# Iteration 200, Training Accuracy= 0.70000, Validation Accuracy= 0.70400
# Iteration 300, Training Accuracy= 0.75400, Validation Accuracy= 0.76200
# Iteration 400, Training Accuracy= 0.75800, Validation Accuracy= 0.75000
# Iteration 500, Training Accuracy= 0.85800, Validation Accuracy= 0.83600
# Iteration 600, Training Accuracy= 0.84800, Validation Accuracy= 0.85800
# Iteration 700, Training Accuracy= 0.86000, Validation Accuracy= 0.89200
# Iteration 800, Training Accuracy= 0.92800, Validation Accuracy= 0.93400
# Iteration 900, Training Accuracy= 0.94200, Validation Accuracy= 0.92400
# Iteration 1000, Training Accuracy= 0.94800, Validation Accuracy= 0.95400
# Iteration 1100, Training Accuracy= 0.95800, Validation Accuracy= 0.95600
# Iteration 1200, Training Accuracy= 0.94000, Validation Accuracy= 0.96400
# Iteration 1300, Training Accuracy= 0.94800, Validation Accuracy= 0.95200
# Iteration 1400, Training Accuracy= 0.96400, Validation Accuracy= 0.96000
# Iteration 1500, Training Accuracy= 0.96800, Validation Accuracy= 0.95000
# Iteration 1600, Training Accuracy= 0.97600, Validation Accuracy= 0.97000
# Iteration 1700, Training Accuracy= 0.96200, Validation Accuracy= 0.97200
# Iteration 1800, Training Accuracy= 0.96200, Validation Accuracy= 0.95800
# Iteration 1900, Training Accuracy= 0.96200, Validation Accuracy= 0.97400
# Iteration 2000, Training Accuracy= 0.96000, Validation Accuracy= 0.95600
#
#
# Training is finished in 846.0 s !
# Final Training Accuracy: 0.96382
# Final Testing Accuracy:  0.95870

# %%
# plot the convergence curve
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))
plt.tight_layout(pad=3.0, h_pad=3.0, w_pad=1.0, rect=None)

ax[0, 0].plot(range(1, len(model1_train_acc)+1), model1_train_acc, 'g-', label='Training Acc')
ax[0, 0].set_title('Basic RNN with 784 steps')
ax[0, 0].set_xlabel('Training Iterations', fontsize=9)
ax[0, 0].set_ylabel('Accuracy')
ax[0, 0].legend(loc='best', fontsize=9)
              
ax[0, 1].plot(range(1, len(model2_train_acc)+1), model2_train_acc, 'c-', label='Training Acc')
ax[0, 1].set_title('LSTM with 784 steps')
ax[0, 1].set_xlabel('Training Iterations', fontsize=9)
# ax[0, 1].set_ylabel('Accuracy')
ax[0, 1].legend(loc='best', fontsize=9)

ax[1, 0].plot(range(1, len(model3_train_acc)+1), model3_train_acc, 'r-', label='Training Acc')
ax[1, 0].set_title('Basic RNN with 28 steps')
ax[1, 0].set_xlabel('Training Iterations', fontsize=9)
ax[1, 0].set_ylabel('Accuracy')
ax[1, 0].legend(loc='best', fontsize=9)

ax[1, 1].plot(range(1, len(model4_train_acc)+1), model4_train_acc, 'y-', label='Training Acc')
ax[1, 1].set_title('LSTM with 28 steps')
ax[1, 1].set_xlabel('Training Iterations', fontsize=9)
# ax[1, 1].set_ylabel('Accuracy')
ax[1, 1].legend(loc='best', fontsize=9)

fig.savefig('./result/convergence_logistic.pdf')
fig.savefig('./result/convergence_logistic.png', dpi=300)
plt.show()
