# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from RNN import RNN

# %matplotlib inline

# load the MNIST dataset
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("data/", one_hot=True)
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# # Part I. Vinalla RNN with Sequence of Pixels

# %%
# define parameters
category = 'basicRNN'
learning_rate = 0.001
max_iters = 2000
batch_size = 128
n_input = 1
n_steps = 784
n_hidden = 100
n_classes = 10
regression = 'logistic'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='C', frequence=1, size=None, show_frequence=100)

# get training accuracy and testing accuracy
model1_train_acc, model1_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model1_train_acc)+1), model1_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model1_cv_acc)+1), model1_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.07031, Validation Accuracy= 0.10938
# Iteration 200, Training Accuracy= 0.13281, Validation Accuracy= 0.10938
# Iteration 300, Training Accuracy= 0.12500, Validation Accuracy= 0.10156
# Iteration 400, Training Accuracy= 0.10156, Validation Accuracy= 0.07031
# Iteration 500, Training Accuracy= 0.07812, Validation Accuracy= 0.14844
# Iteration 600, Training Accuracy= 0.12500, Validation Accuracy= 0.09375
# Iteration 700, Training Accuracy= 0.10938, Validation Accuracy= 0.14062
# Iteration 800, Training Accuracy= 0.14062, Validation Accuracy= 0.05469
# Iteration 900, Training Accuracy= 0.10938, Validation Accuracy= 0.05469
# Iteration 1000, Training Accuracy= 0.10938, Validation Accuracy= 0.12500
# Iteration 1100, Training Accuracy= 0.15625, Validation Accuracy= 0.17188
# Iteration 1200, Training Accuracy= 0.10156, Validation Accuracy= 0.10156
# Iteration 1300, Training Accuracy= 0.07812, Validation Accuracy= 0.11719
# Iteration 1400, Training Accuracy= 0.10156, Validation Accuracy= 0.03906
# Iteration 1500, Training Accuracy= 0.09375, Validation Accuracy= 0.10156
# Iteration 1600, Training Accuracy= 0.09375, Validation Accuracy= 0.04688
# Iteration 1700, Training Accuracy= 0.11719, Validation Accuracy= 0.12500
# Iteration 1800, Training Accuracy= 0.14844, Validation Accuracy= 0.11719
# Iteration 1900, Training Accuracy= 0.14844, Validation Accuracy= 0.10156
# Iteration 2000, Training Accuracy= 0.07031, Validation Accuracy= 0.03906
#
#
# Training is finished in 1507.0 s !
# Final Training Accuracy: 0.09067
# Final Testing Accuracy:  0.08920

# %% [markdown]
# # Part III. Vinalla RNN with Sequence of Columns

# %%
# define parameters
# 28 steps, inputs is 28 column vector
category = 'basicRNN'
learning_rate = 0.001
max_iters = 2000
batch_size = 128
n_input = 28
n_steps = 28
n_hidden = 100
n_classes = 10
regression = 'logistic'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='F', frequence=1, size=None, show_frequence=100)

# get training accuracy and testing accuracy
model3_train_acc, model3_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model3_train_acc)+1), model3_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model3_cv_acc)+1), model3_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.70312, Validation Accuracy= 0.67188
# Iteration 200, Training Accuracy= 0.73438, Validation Accuracy= 0.75000
# Iteration 300, Training Accuracy= 0.83594, Validation Accuracy= 0.76562
# Iteration 400, Training Accuracy= 0.87500, Validation Accuracy= 0.92969
# Iteration 500, Training Accuracy= 0.88281, Validation Accuracy= 0.93750
# Iteration 600, Training Accuracy= 0.84375, Validation Accuracy= 0.88281
# Iteration 700, Training Accuracy= 0.87500, Validation Accuracy= 0.89062
# Iteration 800, Training Accuracy= 0.89844, Validation Accuracy= 0.86719
# Iteration 900, Training Accuracy= 0.89844, Validation Accuracy= 0.85938
# Iteration 1000, Training Accuracy= 0.87500, Validation Accuracy= 0.91406
# Iteration 1100, Training Accuracy= 0.88281, Validation Accuracy= 0.90625
# Iteration 1200, Training Accuracy= 0.93750, Validation Accuracy= 0.92188
# Iteration 1300, Training Accuracy= 0.89844, Validation Accuracy= 0.89062
# Iteration 1400, Training Accuracy= 0.93750, Validation Accuracy= 0.92188
# Iteration 1500, Training Accuracy= 0.89844, Validation Accuracy= 0.97656
# Iteration 1600, Training Accuracy= 0.89844, Validation Accuracy= 0.94531
# Iteration 1700, Training Accuracy= 0.90625, Validation Accuracy= 0.91406
# Iteration 1800, Training Accuracy= 0.86719, Validation Accuracy= 0.86719
# Iteration 1900, Training Accuracy= 0.92188, Validation Accuracy= 0.85938
# Iteration 2000, Training Accuracy= 0.91406, Validation Accuracy= 0.86719
#
#
# Training is finished in 51.0 s !
# Final Training Accuracy: 0.90258
# Final Testing Accuracy:  0.90850

# %% [markdown]
# # Part IV. LSTM with Sequence of Columns

# %%
# define parameters 
# 28 steps, inputs is 28 column vector
category = 'LSTM'
learning_rate = 0.001
max_iters = 2000
batch_size = 128
n_input = 28
n_steps = 28
n_hidden = 100
n_classes = 10
regression = 'logistic'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='F', frequence=1, size=None, show_frequence=100)

# get training accuracy and testing accuracy
model4_train_acc, model4_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model4_train_acc)+1), model4_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model4_cv_acc)+1), model4_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.76562, Validation Accuracy= 0.80469
# Iteration 200, Training Accuracy= 0.90625, Validation Accuracy= 0.94531
# Iteration 300, Training Accuracy= 0.92188, Validation Accuracy= 0.93750
# Iteration 400, Training Accuracy= 0.96094, Validation Accuracy= 0.94531
# Iteration 500, Training Accuracy= 0.95312, Validation Accuracy= 0.94531
# Iteration 600, Training Accuracy= 0.89844, Validation Accuracy= 0.96094
# Iteration 700, Training Accuracy= 0.92969, Validation Accuracy= 0.93750
# Iteration 800, Training Accuracy= 0.99219, Validation Accuracy= 0.93750
# Iteration 900, Training Accuracy= 0.96094, Validation Accuracy= 0.94531
# Iteration 1000, Training Accuracy= 0.95312, Validation Accuracy= 0.94531
# Iteration 1100, Training Accuracy= 0.97656, Validation Accuracy= 0.92969
# Iteration 1200, Training Accuracy= 0.95312, Validation Accuracy= 0.93750
# Iteration 1300, Training Accuracy= 0.94531, Validation Accuracy= 0.96094
# Iteration 1400, Training Accuracy= 0.93750, Validation Accuracy= 0.96094
# Iteration 1500, Training Accuracy= 0.96094, Validation Accuracy= 0.96094
# Iteration 1600, Training Accuracy= 0.99219, Validation Accuracy= 0.94531
# Iteration 1700, Training Accuracy= 0.95312, Validation Accuracy= 0.92969
# Iteration 1800, Training Accuracy= 0.96094, Validation Accuracy= 0.96094
# Iteration 1900, Training Accuracy= 0.95312, Validation Accuracy= 0.96094
# Iteration 2000, Training Accuracy= 0.96875, Validation Accuracy= 0.95312
#
#
# Training is finished in 135.0 s !
# Final Training Accuracy: 0.96905
# Final Testing Accuracy:  0.96710

# %% [markdown]
# # Part II. LSTM with Sequence of Pixels

# %%
# define parameters
category = 'LSTM'
learning_rate = 0.001
max_iters = 1000
batch_size = 128
n_input = 1
n_steps = 784
n_hidden = 100
n_classes = 10
regression = 'logistic'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='C', frequence=1, size=None, show_frequence=50)

# get training accuracy and testing accuracy
model2_train_acc, model2_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model2_train_acc)+1), model2_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model2_cv_acc)+1), model2_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 50, Training Accuracy= 0.09375, Validation Accuracy= 0.08594
# Iteration 100, Training Accuracy= 0.12500, Validation Accuracy= 0.10938
# Iteration 150, Training Accuracy= 0.05469, Validation Accuracy= 0.07031
# Iteration 200, Training Accuracy= 0.10156, Validation Accuracy= 0.07031
# Iteration 250, Training Accuracy= 0.10938, Validation Accuracy= 0.10938
# Iteration 300, Training Accuracy= 0.07031, Validation Accuracy= 0.11719
# Iteration 350, Training Accuracy= 0.16406, Validation Accuracy= 0.15625
# Iteration 400, Training Accuracy= 0.14062, Validation Accuracy= 0.19531
# Iteration 450, Training Accuracy= 0.09375, Validation Accuracy= 0.13281
# Iteration 500, Training Accuracy= 0.08594, Validation Accuracy= 0.13281
# Iteration 550, Training Accuracy= 0.07812, Validation Accuracy= 0.11719
# Iteration 600, Training Accuracy= 0.08594, Validation Accuracy= 0.12500
# Iteration 650, Training Accuracy= 0.14062, Validation Accuracy= 0.14062
# Iteration 700, Training Accuracy= 0.12500, Validation Accuracy= 0.12500
# Iteration 750, Training Accuracy= 0.00781, Validation Accuracy= 0.02344
# Iteration 800, Training Accuracy= 0.14844, Validation Accuracy= 0.10938
# Iteration 850, Training Accuracy= 0.08594, Validation Accuracy= 0.10156
# Iteration 900, Training Accuracy= 0.07812, Validation Accuracy= 0.14062
# Iteration 950, Training Accuracy= 0.03906, Validation Accuracy= 0.03125
# Iteration 1000, Training Accuracy= 0.11719, Validation Accuracy= 0.14844
#
#
# Training is finished in 1868.0 s !
# Final Training Accuracy: 0.10313
# Final Testing Accuracy:  0.10220

# %%
# plot the convergence curve
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))
plt.tight_layout(pad=3.0, h_pad=3.0, w_pad=1.0, rect=None)

ax[0, 0].plot(range(1, len(model1_train_acc)+1), model1_train_acc, 'g-', label='Training Acc')
ax[0, 0].set_title('Basic RNN with 784 steps')
ax[0, 0].set_xlabel('Training Iterations', fontsize=9)
ax[0, 0].set_ylabel('Accuracy')
ax[0, 0].legend(loc='best', fontsize=9)
              
ax[0, 1].plot(range(1, len(model2_train_acc)+1), model2_train_acc, 'c-', label='Training Acc')
ax[0, 1].set_title('LSTM with 784 steps')
ax[0, 1].set_xlabel('Training Iterations', fontsize=9)
# ax[0, 1].set_ylabel('Accuracy')
ax[0, 1].legend(loc='best', fontsize=9)

ax[1, 0].plot(range(1, len(model3_train_acc)+1), model3_train_acc, 'r-', label='Training Acc')
ax[1, 0].set_title('Basic RNN with 28 steps')
ax[1, 0].set_xlabel('Training Iterations', fontsize=9)
ax[1, 0].set_ylabel('Accuracy')
ax[1, 0].legend(loc='best', fontsize=9)

ax[1, 1].plot(range(1, len(model4_train_acc)+1), model4_train_acc, 'y-', label='Training Acc')
ax[1, 1].set_title('LSTM with 28 steps')
ax[1, 1].set_xlabel('Training Iterations', fontsize=9)
# ax[1, 1].set_ylabel('Accuracy')
ax[1, 1].legend(loc='best', fontsize=9)

fig.savefig('./result/convergence_logistic.pdf')
fig.savefig('./result/convergence_logistic.png', dpi=300)
plt.show()
