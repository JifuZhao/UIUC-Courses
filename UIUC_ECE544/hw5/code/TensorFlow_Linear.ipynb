# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from RNN import RNN

# %matplotlib inline

# load the MNIST dataset
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("data/", one_hot=True)
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# # Part I. Vinalla RNN with Sequence of Pixels

# %%
# define parameters
category = 'basicRNN'
learning_rate = 0.001
max_iters = 2000
batch_size = 100
n_input = 1
n_steps = 784
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='C', frequence=1, size=500, show_frequence=100)

# get training accuracy and testing accuracy
model1_train_acc, model1_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model1_train_acc)+1), model1_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model1_cv_acc)+1), model1_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.09400, Validation Accuracy= 0.11200
# Iteration 200, Training Accuracy= 0.10800, Validation Accuracy= 0.10000
# Iteration 300, Training Accuracy= 0.13200, Validation Accuracy= 0.12200
# Iteration 400, Training Accuracy= 0.08000, Validation Accuracy= 0.08800
# Iteration 500, Training Accuracy= 0.10600, Validation Accuracy= 0.09400
# Iteration 600, Training Accuracy= 0.08000, Validation Accuracy= 0.08800
# Iteration 700, Training Accuracy= 0.09200, Validation Accuracy= 0.07800
# Iteration 800, Training Accuracy= 0.08400, Validation Accuracy= 0.08800
# Iteration 900, Training Accuracy= 0.03000, Validation Accuracy= 0.03000
# Iteration 1000, Training Accuracy= 0.12400, Validation Accuracy= 0.14000
# Iteration 1100, Training Accuracy= 0.10200, Validation Accuracy= 0.11200
# Iteration 1200, Training Accuracy= 0.09200, Validation Accuracy= 0.08200
# Iteration 1300, Training Accuracy= 0.09400, Validation Accuracy= 0.07600
# Iteration 1400, Training Accuracy= 0.06800, Validation Accuracy= 0.07400
# Iteration 1500, Training Accuracy= 0.11200, Validation Accuracy= 0.10600
# Iteration 1600, Training Accuracy= 0.11000, Validation Accuracy= 0.12400
# Iteration 1700, Training Accuracy= 0.08000, Validation Accuracy= 0.12200
# Iteration 1800, Training Accuracy= 0.11400, Validation Accuracy= 0.08800
# Iteration 1900, Training Accuracy= 0.10400, Validation Accuracy= 0.10800
# Iteration 2000, Training Accuracy= 0.14200, Validation Accuracy= 0.10600
#
#
# Training is finished in 9798.0 s !
# Final Training Accuracy: 0.12196
# Final Testing Accuracy:  0.11970

# %% [markdown]
# # Part II. LSTM with Sequence of Pixels

# %%
# define parameters
category = 'LSTM'
learning_rate = 0.001
max_iters = 1000
batch_size = 100
n_input = 1
n_steps = 784
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='C', frequence=1, size=500, show_frequence=50)

# get training accuracy and testing accuracy
model2_train_acc, model2_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model2_train_acc)+1), model2_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model2_cv_acc)+1), model2_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 50, Training Accuracy= 0.10800, Validation Accuracy= 0.10400
# Iteration 100, Training Accuracy= 0.27200, Validation Accuracy= 0.24000
# Iteration 150, Training Accuracy= 0.10600, Validation Accuracy= 0.13000
# Iteration 200, Training Accuracy= 0.21600, Validation Accuracy= 0.18400
# Iteration 250, Training Accuracy= 0.28400, Validation Accuracy= 0.28200
# Iteration 300, Training Accuracy= 0.30600, Validation Accuracy= 0.29400
# Iteration 350, Training Accuracy= 0.38400, Validation Accuracy= 0.37000
# Iteration 400, Training Accuracy= 0.32600, Validation Accuracy= 0.38000
# Iteration 450, Training Accuracy= 0.36800, Validation Accuracy= 0.39600
# Iteration 500, Training Accuracy= 0.36800, Validation Accuracy= 0.34400
# Iteration 550, Training Accuracy= 0.40600, Validation Accuracy= 0.41400
# Iteration 600, Training Accuracy= 0.35400, Validation Accuracy= 0.33600
# Iteration 650, Training Accuracy= 0.41800, Validation Accuracy= 0.43800
# Iteration 700, Training Accuracy= 0.40800, Validation Accuracy= 0.43600
# Iteration 750, Training Accuracy= 0.34200, Validation Accuracy= 0.43600
# Iteration 800, Training Accuracy= 0.44000, Validation Accuracy= 0.45600
# Iteration 850, Training Accuracy= 0.45800, Validation Accuracy= 0.48400
# Iteration 900, Training Accuracy= 0.42800, Validation Accuracy= 0.43400
# Iteration 950, Training Accuracy= 0.51000, Validation Accuracy= 0.51800
# Iteration 1000, Training Accuracy= 0.47000, Validation Accuracy= 0.49200
#
#
# Training is finished in 11091.0 s !
# Final Training Accuracy: 0.45695
# Final Testing Accuracy:  0.45700

# %% [markdown]
# # Part III. Vinalla RNN with Sequence of Columns

# %%
# define parameters
# 28 steps, inputs is 28 column vector
category = 'basicRNN'
learning_rate = 0.001
max_iters = 2000
batch_size = 100
n_input = 28
n_steps = 28
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='F', frequence=1, size=500, show_frequence=100)

# get training accuracy and testing accuracy
model3_train_acc, model3_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model3_train_acc)+1), model3_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model3_cv_acc)+1), model3_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.78400, Validation Accuracy= 0.81600
# Iteration 200, Training Accuracy= 0.84200, Validation Accuracy= 0.84600
# Iteration 300, Training Accuracy= 0.87800, Validation Accuracy= 0.88800
# Iteration 400, Training Accuracy= 0.84400, Validation Accuracy= 0.87000
# Iteration 500, Training Accuracy= 0.91200, Validation Accuracy= 0.88400
# Iteration 600, Training Accuracy= 0.88200, Validation Accuracy= 0.88400
# Iteration 700, Training Accuracy= 0.88400, Validation Accuracy= 0.91200
# Iteration 800, Training Accuracy= 0.93400, Validation Accuracy= 0.90600
# Iteration 900, Training Accuracy= 0.89800, Validation Accuracy= 0.91400
# Iteration 1000, Training Accuracy= 0.93400, Validation Accuracy= 0.92800
# Iteration 1100, Training Accuracy= 0.89400, Validation Accuracy= 0.92200
# Iteration 1200, Training Accuracy= 0.92200, Validation Accuracy= 0.92800
# Iteration 1300, Training Accuracy= 0.92000, Validation Accuracy= 0.94400
# Iteration 1400, Training Accuracy= 0.92200, Validation Accuracy= 0.94600
# Iteration 1500, Training Accuracy= 0.89200, Validation Accuracy= 0.92400
# Iteration 1600, Training Accuracy= 0.93400, Validation Accuracy= 0.93000
# Iteration 1700, Training Accuracy= 0.92800, Validation Accuracy= 0.94800
# Iteration 1800, Training Accuracy= 0.92400, Validation Accuracy= 0.95600
# Iteration 1900, Training Accuracy= 0.94600, Validation Accuracy= 0.93000
# Iteration 2000, Training Accuracy= 0.94600, Validation Accuracy= 0.92800
#
#
# Training is finished in 402.0 s !
# Final Training Accuracy: 0.95060
# Final Testing Accuracy:  0.95170

# %% [markdown]
# # Part IV. LSTM with Sequence of Columns

# %%
# define parameters 
# 28 steps, inputs is 28 column vector
category = 'LSTM'
learning_rate = 0.001
max_iters = 2000
batch_size = 100
n_input = 28
n_steps = 28
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='F', frequence=1, size=500, show_frequence=100)

# get training accuracy and testing accuracy
model4_train_acc, model4_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model4_train_acc)+1), model4_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model4_cv_acc)+1), model4_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.86400, Validation Accuracy= 0.88600
# Iteration 200, Training Accuracy= 0.90400, Validation Accuracy= 0.95200
# Iteration 300, Training Accuracy= 0.95000, Validation Accuracy= 0.93800
# Iteration 400, Training Accuracy= 0.95000, Validation Accuracy= 0.94400
# Iteration 500, Training Accuracy= 0.95600, Validation Accuracy= 0.95000
# Iteration 600, Training Accuracy= 0.96000, Validation Accuracy= 0.95600
# Iteration 700, Training Accuracy= 0.97000, Validation Accuracy= 0.98000
# Iteration 800, Training Accuracy= 0.96200, Validation Accuracy= 0.97600
# Iteration 900, Training Accuracy= 0.95800, Validation Accuracy= 0.96800
# Iteration 1000, Training Accuracy= 0.97000, Validation Accuracy= 0.98000
# Iteration 1100, Training Accuracy= 0.97000, Validation Accuracy= 0.97000
# Iteration 1200, Training Accuracy= 0.96600, Validation Accuracy= 0.97200
# Iteration 1300, Training Accuracy= 0.97800, Validation Accuracy= 0.97000
# Iteration 1400, Training Accuracy= 0.96800, Validation Accuracy= 0.97200
# Iteration 1500, Training Accuracy= 0.97400, Validation Accuracy= 0.95800
# Iteration 1600, Training Accuracy= 0.98600, Validation Accuracy= 0.96600
# Iteration 1700, Training Accuracy= 0.98200, Validation Accuracy= 0.98200
# Iteration 1800, Training Accuracy= 0.98600, Validation Accuracy= 0.97800
# Iteration 1900, Training Accuracy= 0.97200, Validation Accuracy= 0.98000
# Iteration 2000, Training Accuracy= 0.99000, Validation Accuracy= 0.98400
#
#
# Training is finished in 896.0 s !
# Final Training Accuracy: 0.98211
# Final Testing Accuracy:  0.97860

# %%
# plot the convergence curve
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))
plt.tight_layout(pad=3.0, h_pad=3.0, w_pad=1.0, rect=None)

ax[0, 0].plot(range(1, len(model1_train_acc)+1), model1_train_acc, 'g-', label='Training Acc')
ax[0, 0].set_title('Basic RNN with 784 steps')
ax[0, 0].set_xlabel('Training Iterations', fontsize=9)
ax[0, 0].set_ylabel('Accuracy')
ax[0, 0].legend(loc='best', fontsize=9)
              
ax[0, 1].plot(range(1, len(model2_train_acc)+1), model2_train_acc, 'c-', label='Training Acc')
ax[0, 1].set_title('LSTM with 784 steps')
ax[0, 1].set_xlabel('Training Iterations', fontsize=9)
# ax[0, 1].set_ylabel('Accuracy')
ax[0, 1].legend(loc='best', fontsize=9)

ax[1, 0].plot(range(1, len(model3_train_acc)+1), model3_train_acc, 'r-', label='Training Acc')
ax[1, 0].set_title('Basic RNN with 28 steps')
ax[1, 0].set_xlabel('Training Iterations', fontsize=9)
ax[1, 0].set_ylabel('Accuracy')
ax[1, 0].legend(loc='best', fontsize=9)

ax[1, 1].plot(range(1, len(model4_train_acc)+1), model4_train_acc, 'y-', label='Training Acc')
ax[1, 1].set_title('LSTM with 28 steps')
ax[1, 1].set_xlabel('Training Iterations', fontsize=9)
# ax[1, 1].set_ylabel('Accuracy')
ax[1, 1].legend(loc='best', fontsize=9)

fig.savefig('./result/convergence_linear.pdf')
fig.savefig('./result/convergence_linear.png', dpi=300)
plt.show()
