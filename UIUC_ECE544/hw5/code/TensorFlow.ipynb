# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from RNN import RNN

# %matplotlib inline

# load the MNIST dataset
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("data/", one_hot=True)
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# # Part I. Vinalla RNN with Sequence of Pixels

# %%
# define parameters
category = 'basicRNN'
learning_rate = 0.0005
max_iters = 2000
batch_size = 100
n_input = 1
n_steps = 784
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='C', frequence=1, size=None, show_frequence=100)

# get training accuracy and testing accuracy
model1_train_acc, model1_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model1_train_acc)+1), model1_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model1_cv_acc)+1), model1_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.19000, Validation Accuracy= 0.21000
# Iteration 200, Training Accuracy= 0.18000, Validation Accuracy= 0.19000
# Iteration 300, Training Accuracy= 0.12000, Validation Accuracy= 0.13000
# Iteration 400, Training Accuracy= 0.10000, Validation Accuracy= 0.07000
# Iteration 500, Training Accuracy= 0.16000, Validation Accuracy= 0.15000
# Iteration 600, Training Accuracy= 0.11000, Validation Accuracy= 0.11000
# Iteration 700, Training Accuracy= 0.19000, Validation Accuracy= 0.06000
# Iteration 800, Training Accuracy= 0.18000, Validation Accuracy= 0.18000
# Iteration 900, Training Accuracy= 0.21000, Validation Accuracy= 0.19000
# Iteration 1000, Training Accuracy= 0.17000, Validation Accuracy= 0.12000
# Iteration 1100, Training Accuracy= 0.22000, Validation Accuracy= 0.23000
# Iteration 1200, Training Accuracy= 0.20000, Validation Accuracy= 0.14000
# Iteration 1300, Training Accuracy= 0.13000, Validation Accuracy= 0.16000
# Iteration 1400, Training Accuracy= 0.20000, Validation Accuracy= 0.18000
# Iteration 1500, Training Accuracy= 0.15000, Validation Accuracy= 0.23000
# Iteration 1600, Training Accuracy= 0.20000, Validation Accuracy= 0.21000
# Iteration 1700, Training Accuracy= 0.19000, Validation Accuracy= 0.16000
# Iteration 1800, Training Accuracy= 0.24000, Validation Accuracy= 0.21000
# Iteration 1900, Training Accuracy= 0.21000, Validation Accuracy= 0.22000
# Iteration 2000, Training Accuracy= 0.24000, Validation Accuracy= 0.12000
#
#
# Training is finished in 947.0 s !
# Final Training Accuracy: 0.20400
# Final Testing Accuracy:  0.20950

# %% [markdown]
# # Part II. LSTM with Sequence of Pixels

# %%
# define parameters
category = 'LSTM'
learning_rate = 0.0001
max_iters = 1000
batch_size = 100
n_input = 1
n_steps = 784
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='C', frequence=1, size=None, show_frequence=50)

# get training accuracy and testing accuracy
model2_train_acc, model2_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model2_train_acc)+1), model2_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model2_cv_acc)+1), model2_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 50, Training Accuracy= 0.14000, Validation Accuracy= 0.18000
# Iteration 100, Training Accuracy= 0.25000, Validation Accuracy= 0.19000
# Iteration 150, Training Accuracy= 0.28000, Validation Accuracy= 0.27000
# Iteration 200, Training Accuracy= 0.34000, Validation Accuracy= 0.40000
# Iteration 250, Training Accuracy= 0.22000, Validation Accuracy= 0.36000
# Iteration 300, Training Accuracy= 0.30000, Validation Accuracy= 0.29000
# Iteration 350, Training Accuracy= 0.25000, Validation Accuracy= 0.36000
# Iteration 400, Training Accuracy= 0.39000, Validation Accuracy= 0.34000
# Iteration 450, Training Accuracy= 0.33000, Validation Accuracy= 0.42000
# Iteration 500, Training Accuracy= 0.38000, Validation Accuracy= 0.28000
# Iteration 550, Training Accuracy= 0.41000, Validation Accuracy= 0.41000
# Iteration 600, Training Accuracy= 0.26000, Validation Accuracy= 0.28000
# Iteration 650, Training Accuracy= 0.37000, Validation Accuracy= 0.44000
# Iteration 700, Training Accuracy= 0.47000, Validation Accuracy= 0.44000
# Iteration 750, Training Accuracy= 0.33000, Validation Accuracy= 0.35000
# Iteration 800, Training Accuracy= 0.40000, Validation Accuracy= 0.53000
# Iteration 850, Training Accuracy= 0.44000, Validation Accuracy= 0.47000
# Iteration 900, Training Accuracy= 0.26000, Validation Accuracy= 0.24000
# Iteration 950, Training Accuracy= 0.31000, Validation Accuracy= 0.40000
# Iteration 1000, Training Accuracy= 0.30000, Validation Accuracy= 0.44000
#
#
# Training is finished in 1428.0 s !
# Final Training Accuracy: 0.40815
# Final Testing Accuracy:  0.40760

# %% [markdown]
# # Part III. Vinalla RNN with Sequence of Columns

# %%
# define parameters
# 28 steps, inputs is 28 column vector
category = 'basicRNN'
learning_rate = 0.0001
max_iters = 5000
batch_size = 100
n_input = 28
n_steps = 28
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='F', frequence=1, size=None, show_frequence=500)

# get training accuracy and testing accuracy
model3_train_acc, model3_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model3_train_acc)+1), model3_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model3_cv_acc)+1), model3_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 500, Training Accuracy= 0.86000, Validation Accuracy= 0.84000
# Iteration 1000, Training Accuracy= 0.86000, Validation Accuracy= 0.91000
# Iteration 1500, Training Accuracy= 0.84000, Validation Accuracy= 0.93000
# Iteration 2000, Training Accuracy= 0.93000, Validation Accuracy= 0.95000
# Iteration 2500, Training Accuracy= 0.92000, Validation Accuracy= 0.87000
# Iteration 3000, Training Accuracy= 0.89000, Validation Accuracy= 0.94000
# Iteration 3500, Training Accuracy= 0.93000, Validation Accuracy= 0.93000
# Iteration 4000, Training Accuracy= 0.91000, Validation Accuracy= 0.92000
# Iteration 4500, Training Accuracy= 0.95000, Validation Accuracy= 0.97000
# Iteration 5000, Training Accuracy= 0.95000, Validation Accuracy= 0.94000
#
#
# Training is finished in 98.0 s !
# Final Training Accuracy: 0.93607
# Final Testing Accuracy:  0.94200

# %% [markdown]
# # Part IV. LSTM with Sequence of Columns

# %%
# define parameters 
# 28 steps, inputs is 28 column vector
category = 'LSTM'
learning_rate = 0.0001
max_iters = 5000
batch_size = 100
n_input = 28
n_steps = 28
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='F', frequence=1, size=None, show_frequence=500)

# get training accuracy and testing accuracy
model4_train_acc, model4_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model4_train_acc)+1), model4_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model4_cv_acc)+1), model4_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.46000, Validation Accuracy= 0.40000
# Iteration 200, Training Accuracy= 0.67000, Validation Accuracy= 0.78000
# Iteration 300, Training Accuracy= 0.79000, Validation Accuracy= 0.74000
# Iteration 400, Training Accuracy= 0.81000, Validation Accuracy= 0.77000
# Iteration 500, Training Accuracy= 0.82000, Validation Accuracy= 0.79000
# Iteration 600, Training Accuracy= 0.90000, Validation Accuracy= 0.89000
# Iteration 700, Training Accuracy= 0.90000, Validation Accuracy= 0.91000
# Iteration 800, Training Accuracy= 0.91000, Validation Accuracy= 0.92000
# Iteration 900, Training Accuracy= 0.89000, Validation Accuracy= 0.93000
# Iteration 1000, Training Accuracy= 0.88000, Validation Accuracy= 0.92000
# Iteration 1100, Training Accuracy= 0.96000, Validation Accuracy= 0.91000
# Iteration 1200, Training Accuracy= 0.85000, Validation Accuracy= 0.91000
# Iteration 1300, Training Accuracy= 0.93000, Validation Accuracy= 0.91000
# Iteration 1400, Training Accuracy= 0.93000, Validation Accuracy= 0.93000
# Iteration 1500, Training Accuracy= 0.94000, Validation Accuracy= 0.94000
# Iteration 1600, Training Accuracy= 0.92000, Validation Accuracy= 0.92000
# Iteration 1700, Training Accuracy= 0.99000, Validation Accuracy= 0.94000
# Iteration 1800, Training Accuracy= 0.94000, Validation Accuracy= 0.93000
# Iteration 1900, Training Accuracy= 0.94000, Validation Accuracy= 0.94000
# Iteration 2000, Training Accuracy= 0.91000, Validation Accuracy= 0.95000
# Iteration 2100, Training Accuracy= 0.96000, Validation Accuracy= 0.92000
# Iteration 2200, Training Accuracy= 0.93000, Validation Accuracy= 0.94000
# Iteration 2300, Training Accuracy= 0.95000, Validation Accuracy= 0.91000
# Iteration 2400, Training Accuracy= 0.94000, Validation Accuracy= 0.96000
# Iteration 2500, Training Accuracy= 0.98000, Validation Accuracy= 0.96000
# Iteration 2600, Training Accuracy= 0.96000, Validation Accuracy= 0.98000
# Iteration 2700, Training Accuracy= 0.93000, Validation Accuracy= 0.96000
# Iteration 2800, Training Accuracy= 0.94000, Validation Accuracy= 0.97000
# Iteration 2900, Training Accuracy= 0.97000, Validation Accuracy= 0.92000
# Iteration 3000, Training Accuracy= 0.97000, Validation Accuracy= 0.95000
# Iteration 3100, Training Accuracy= 0.96000, Validation Accuracy= 0.98000
# Iteration 3200, Training Accuracy= 0.95000, Validation Accuracy= 0.95000
# Iteration 3300, Training Accuracy= 0.90000, Validation Accuracy= 0.98000
# Iteration 3400, Training Accuracy= 0.96000, Validation Accuracy= 0.96000
# Iteration 3500, Training Accuracy= 0.98000, Validation Accuracy= 0.96000
# Iteration 3600, Training Accuracy= 0.94000, Validation Accuracy= 0.95000
# Iteration 3700, Training Accuracy= 0.96000, Validation Accuracy= 0.96000
# Iteration 3800, Training Accuracy= 0.96000, Validation Accuracy= 0.96000
# Iteration 3900, Training Accuracy= 0.97000, Validation Accuracy= 0.95000
# Iteration 4000, Training Accuracy= 0.96000, Validation Accuracy= 0.98000
# Iteration 4100, Training Accuracy= 0.96000, Validation Accuracy= 0.99000
# Iteration 4200, Training Accuracy= 0.95000, Validation Accuracy= 0.98000
# Iteration 4300, Training Accuracy= 0.97000, Validation Accuracy= 0.96000
# Iteration 4400, Training Accuracy= 0.98000, Validation Accuracy= 0.97000
# Iteration 4500, Training Accuracy= 0.99000, Validation Accuracy= 0.97000
# Iteration 4600, Training Accuracy= 0.98000, Validation Accuracy= 0.97000
# Iteration 4700, Training Accuracy= 0.99000, Validation Accuracy= 0.97000
# Iteration 4800, Training Accuracy= 0.98000, Validation Accuracy= 0.98000
# Iteration 4900, Training Accuracy= 0.98000, Validation Accuracy= 0.93000
# Iteration 5000, Training Accuracy= 0.98000, Validation Accuracy= 0.99000
#
#
# Training is finished in 263.0 s !
# Final Training Accuracy: 0.96676
# Final Testing Accuracy:  0.96510

# %%
# plot the convergence curve
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))
plt.tight_layout(pad=3.0, h_pad=3.5, w_pad=1.0, rect=None)

ax[0, 0].plot(range(1, len(model1_train_acc)+1), model1_train_acc, 
              'g-', label='Training Acc')
ax[0, 0].set_ylim([0, 0.4])
ax[0, 0].set_title('Basic RNN with 784 steps')
ax[0, 0].set_xlabel('Training Iterations', fontsize=9)
ax[0, 0].set_ylabel('Accuracy')
ax[0, 0].legend(loc='best', fontsize=10)
              
ax[0, 1].plot(range(1, len(model2_train_acc)+1), model2_train_acc, 
              'c-', label='Training Acc')
ax[0, 1].set_title('LSTM with 784 steps')
ax[0, 1].set_xlabel('Training Iterations', fontsize=9)
ax[0, 1].legend(loc='best', fontsize=10)

ax[1, 0].plot(range(1, len(model3_train_acc)+1), model3_train_acc, 
              'r-', label='Training Acc')
ax[1, 0].set_title('Basic RNN with 28 steps')
ax[1, 0].set_xlabel('Training Iterations', fontsize=9)
ax[1, 0].set_ylabel('Accuracy')
ax[1, 0].legend(loc=4, fontsize=10)

ax[1, 1].plot(range(1, len(model4_train_acc)+1), model4_train_acc, 
              'y-', label='Training Acc')
ax[1, 1].set_title('LSTM with 28 steps')
ax[1, 1].set_xlabel('Training Iterations', fontsize=9)
ax[1, 1].legend(loc=4, fontsize=10)

fig.savefig('./result/convergence.pdf')
fig.savefig('./result/convergence.png', dpi=300)
plt.show()
