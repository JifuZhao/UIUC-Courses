# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from RNN import RNN

# %matplotlib inline

# load the MNIST dataset
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("data/", one_hot=True)
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# # Part I. Vinalla RNN with Sequence of Pixels

# %%
# define parameters
category = 'basicRNN'
learning_rate = 0.001
max_iters = 2000
batch_size = 500
n_input = 1
n_steps = 784
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='C', frequence=1, size=500, show_frequence=100)

# get training accuracy and testing accuracy
model1_train_acc, model1_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model1_train_acc)+1), model1_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model1_cv_acc)+1), model1_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.11200, Validation Accuracy= 0.10000
# Iteration 200, Training Accuracy= 0.08000, Validation Accuracy= 0.09200
# Iteration 300, Training Accuracy= 0.10600, Validation Accuracy= 0.11600
# Iteration 400, Training Accuracy= 0.10400, Validation Accuracy= 0.09800
# Iteration 500, Training Accuracy= 0.08600, Validation Accuracy= 0.09600
# Iteration 600, Training Accuracy= 0.12800, Validation Accuracy= 0.11000
# Iteration 700, Training Accuracy= 0.12200, Validation Accuracy= 0.11800
# Iteration 800, Training Accuracy= 0.12000, Validation Accuracy= 0.13600
# Iteration 900, Training Accuracy= 0.13600, Validation Accuracy= 0.14200
# Iteration 1000, Training Accuracy= 0.11400, Validation Accuracy= 0.13200
# Iteration 1100, Training Accuracy= 0.10600, Validation Accuracy= 0.11800
# Iteration 1200, Training Accuracy= 0.09000, Validation Accuracy= 0.08200
# Iteration 1300, Training Accuracy= 0.09800, Validation Accuracy= 0.09200
# Iteration 1400, Training Accuracy= 0.10200, Validation Accuracy= 0.09000
# Iteration 1500, Training Accuracy= 0.09400, Validation Accuracy= 0.09000
# Iteration 1600, Training Accuracy= 0.08800, Validation Accuracy= 0.10200
# Iteration 1700, Training Accuracy= 0.10400, Validation Accuracy= 0.10400
# Iteration 1800, Training Accuracy= 0.12800, Validation Accuracy= 0.11800
# Iteration 1900, Training Accuracy= 0.11600, Validation Accuracy= 0.13200
# Iteration 2000, Training Accuracy= 0.12000, Validation Accuracy= 0.12200
#
#
# Training is finished in 16912.0 s !
# Final Training Accuracy: 0.09947
# Final Testing Accuracy:  0.09660

# %% [markdown]
# # Part II. LSTM with Sequence of Pixels

# %%
# define parameters
category = 'LSTM'
learning_rate = 0.001
max_iters = 1000
batch_size = 500
n_input = 1
n_steps = 784
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='C', frequence=1, size=500, show_frequence=50)

# get training accuracy and testing accuracy
model2_train_acc, model2_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model2_train_acc)+1), model2_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model2_cv_acc)+1), model2_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 50, Training Accuracy= 0.15600, Validation Accuracy= 0.17400
# Iteration 100, Training Accuracy= 0.36800, Validation Accuracy= 0.33800
# Iteration 150, Training Accuracy= 0.28800, Validation Accuracy= 0.28200
# Iteration 200, Training Accuracy= 0.39800, Validation Accuracy= 0.39400
# Iteration 250, Training Accuracy= 0.46000, Validation Accuracy= 0.43200
# Iteration 300, Training Accuracy= 0.39400, Validation Accuracy= 0.44000
# Iteration 350, Training Accuracy= 0.46600, Validation Accuracy= 0.46200
# Iteration 400, Training Accuracy= 0.47200, Validation Accuracy= 0.49200
# Iteration 450, Training Accuracy= 0.53600, Validation Accuracy= 0.55200
# Iteration 500, Training Accuracy= 0.49400, Validation Accuracy= 0.51200
# Iteration 550, Training Accuracy= 0.53200, Validation Accuracy= 0.58200
# Iteration 600, Training Accuracy= 0.54200, Validation Accuracy= 0.56400
# Iteration 650, Training Accuracy= 0.53600, Validation Accuracy= 0.57400
# Iteration 700, Training Accuracy= 0.57000, Validation Accuracy= 0.58200
# Iteration 750, Training Accuracy= 0.10000, Validation Accuracy= 0.14000
# Iteration 800, Training Accuracy= 0.26200, Validation Accuracy= 0.27600
# Iteration 850, Training Accuracy= 0.09800, Validation Accuracy= 0.07000
# Iteration 900, Training Accuracy= 0.10000, Validation Accuracy= 0.09600

# %% [markdown]
# # Part III. Vinalla RNN with Sequence of Columns

# %%
# define parameters
# 28 steps, inputs is 28 column vector
category = 'basicRNN'
learning_rate = 0.001
max_iters = 2000
batch_size = 500
n_input = 28
n_steps = 28
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='F', frequence=1, size=500, show_frequence=100)

# get training accuracy and testing accuracy
model3_train_acc, model3_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model3_train_acc)+1), model3_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model3_cv_acc)+1), model3_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()

# %% [markdown]
# # Part IV. LSTM with Sequence of Columns

# %%
# define parameters 
# 28 steps, inputs is 28 column vector
category = 'LSTM'
learning_rate = 0.001
max_iters = 2000
batch_size = 500
n_input = 28
n_steps = 28
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='F', frequence=1, size=500, show_frequence=100)

# get training accuracy and testing accuracy
model4_train_acc, model4_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model4_train_acc)+1), model4_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model4_cv_acc)+1), model4_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()

# %%
# plot the convergence curve
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))
plt.tight_layout(pad=3.0, h_pad=3.0, w_pad=1.0, rect=None)

ax[0, 0].plot(range(1, len(model1_train_acc)+1), model1_train_acc, 'g-', label='Training Acc')
ax[0, 0].set_title('Basic RNN with 784 steps')
ax[0, 0].set_xlabel('Training Iterations', fontsize=9)
ax[0, 0].set_ylabel('Accuracy')
ax[0, 0].legend(loc='best', fontsize=9)
              
ax[0, 1].plot(range(1, len(model2_train_acc)+1), model2_train_acc, 'c-', label='Training Acc')
ax[0, 1].set_title('LSTM with 784 steps')
ax[0, 1].set_xlabel('Training Iterations', fontsize=9)
# ax[0, 1].set_ylabel('Accuracy')
ax[0, 1].legend(loc='best', fontsize=9)

ax[1, 0].plot(range(1, len(model3_train_acc)+1), model3_train_acc, 'r-', label='Training Acc')
ax[1, 0].set_title('Basic RNN with 28 steps')
ax[1, 0].set_xlabel('Training Iterations', fontsize=9)
ax[1, 0].set_ylabel('Accuracy')
ax[1, 0].legend(loc='best', fontsize=9)

ax[1, 1].plot(range(1, len(model4_train_acc)+1), model4_train_acc, 'y-', label='Training Acc')
ax[1, 1].set_title('LSTM with 28 steps')
ax[1, 1].set_xlabel('Training Iterations', fontsize=9)
# ax[1, 1].set_ylabel('Accuracy')
ax[1, 1].legend(loc='best', fontsize=9)

fig.savefig('./result/convergence_linear_big.pdf')
fig.savefig('./result/convergence_linear_big.png', dpi=300)
plt.show()
