# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from RNN import RNN

# %matplotlib inline

# load the MNIST dataset
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("data/", one_hot=True)
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# # Part I. Vinalla RNN with Sequence of Pixels

# %%
# define parameters
category = 'basicRNN'
learning_rate = 0.001
max_iters = 2000
batch_size = 50
n_input = 1
n_steps = 784
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='C', frequence=1, size=500, show_frequence=100)

# get training accuracy and testing accuracy
model1_train_acc, model1_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model1_train_acc)+1), model1_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model1_cv_acc)+1), model1_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.09375, Validation Accuracy= 0.12500
# Iteration 200, Training Accuracy= 0.07812, Validation Accuracy= 0.11719
# Iteration 300, Training Accuracy= 0.17969, Validation Accuracy= 0.14062
# Iteration 400, Training Accuracy= 0.10938, Validation Accuracy= 0.07031
# Iteration 500, Training Accuracy= 0.14062, Validation Accuracy= 0.14844
# Iteration 600, Training Accuracy= 0.11719, Validation Accuracy= 0.10156
# Iteration 700, Training Accuracy= 0.14062, Validation Accuracy= 0.10156
# Iteration 800, Training Accuracy= 0.11719, Validation Accuracy= 0.14062
# Iteration 900, Training Accuracy= 0.13281, Validation Accuracy= 0.14062
# Iteration 1000, Training Accuracy= 0.09375, Validation Accuracy= 0.09375
# Iteration 1100, Training Accuracy= 0.08594, Validation Accuracy= 0.15625
# Iteration 1200, Training Accuracy= 0.12500, Validation Accuracy= 0.10156
# Iteration 1300, Training Accuracy= 0.23438, Validation Accuracy= 0.13281
# Iteration 1400, Training Accuracy= 0.14062, Validation Accuracy= 0.05469
# Iteration 1500, Training Accuracy= 0.10938, Validation Accuracy= 0.09375
# Iteration 1600, Training Accuracy= 0.23438, Validation Accuracy= 0.21094
# Iteration 1700, Training Accuracy= 0.14844, Validation Accuracy= 0.12500
# Iteration 1800, Training Accuracy= 0.09375, Validation Accuracy= 0.12500
# Iteration 1900, Training Accuracy= 0.05469, Validation Accuracy= 0.14844
# Iteration 2000, Training Accuracy= 0.10938, Validation Accuracy= 0.14844
#
#
# Training is finished in 1034.0 s !
# Final Training Accuracy: 0.12211
# Final Testing Accuracy:  0.12020

# %% [markdown]
# # Part III. Vinalla RNN with Sequence of Columns

# %%
# define parameters
# 28 steps, inputs is 28 column vector
category = 'basicRNN'
learning_rate = 0.001
max_iters = 2000
batch_size = 50
n_input = 28
n_steps = 28
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='F', frequence=1, size=500, show_frequence=100)

# get training accuracy and testing accuracy
model3_train_acc, model3_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model3_train_acc)+1), model3_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model3_cv_acc)+1), model3_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.81250, Validation Accuracy= 0.84375
# Iteration 200, Training Accuracy= 0.85156, Validation Accuracy= 0.79688
# Iteration 300, Training Accuracy= 0.85156, Validation Accuracy= 0.82812
# Iteration 400, Training Accuracy= 0.89844, Validation Accuracy= 0.88281
# Iteration 500, Training Accuracy= 0.86719, Validation Accuracy= 0.94531
# Iteration 600, Training Accuracy= 0.91406, Validation Accuracy= 0.92969
# Iteration 700, Training Accuracy= 0.89844, Validation Accuracy= 0.92969
# Iteration 800, Training Accuracy= 0.88281, Validation Accuracy= 0.96094
# Iteration 900, Training Accuracy= 0.85938, Validation Accuracy= 0.95312
# Iteration 1000, Training Accuracy= 0.93750, Validation Accuracy= 0.89844
# Iteration 1100, Training Accuracy= 0.92188, Validation Accuracy= 0.90625
# Iteration 1200, Training Accuracy= 0.93750, Validation Accuracy= 0.90625
# Iteration 1300, Training Accuracy= 0.92969, Validation Accuracy= 0.96875
# Iteration 1400, Training Accuracy= 0.96875, Validation Accuracy= 0.90625
# Iteration 1500, Training Accuracy= 0.93750, Validation Accuracy= 0.92969
# Iteration 1600, Training Accuracy= 0.98438, Validation Accuracy= 0.92969
# Iteration 1700, Training Accuracy= 0.95312, Validation Accuracy= 0.94531
# Iteration 1800, Training Accuracy= 0.95312, Validation Accuracy= 0.96094
# Iteration 1900, Training Accuracy= 0.96875, Validation Accuracy= 0.95312
# Iteration 2000, Training Accuracy= 0.93750, Validation Accuracy= 0.92969
#
#
# Training is finished in 49.0 s !
# Final Training Accuracy: 0.94353
# Final Testing Accuracy:  0.94650

# %% [markdown]
# # Part IV. LSTM with Sequence of Columns

# %%
# define parameters 
# 28 steps, inputs is 28 column vector
category = 'LSTM'
learning_rate = 0.001
max_iters = 2000
batch_size = 50
n_input = 28
n_steps = 28
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='F', frequence=1, size=500, show_frequence=100)

# get training accuracy and testing accuracy
model4_train_acc, model4_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model4_train_acc)+1), model4_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model4_cv_acc)+1), model4_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.89062, Validation Accuracy= 0.89844
# Iteration 200, Training Accuracy= 0.92188, Validation Accuracy= 0.92969
# Iteration 300, Training Accuracy= 0.92969, Validation Accuracy= 0.92969
# Iteration 400, Training Accuracy= 0.92188, Validation Accuracy= 0.97656
# Iteration 500, Training Accuracy= 0.92969, Validation Accuracy= 0.96094
# Iteration 600, Training Accuracy= 0.94531, Validation Accuracy= 0.98438
# Iteration 700, Training Accuracy= 0.96875, Validation Accuracy= 0.95312
# Iteration 800, Training Accuracy= 0.98438, Validation Accuracy= 0.92188
# Iteration 900, Training Accuracy= 0.96094, Validation Accuracy= 0.97656
# Iteration 1000, Training Accuracy= 0.98438, Validation Accuracy= 0.99219
# Iteration 1100, Training Accuracy= 0.97656, Validation Accuracy= 0.99219
# Iteration 1200, Training Accuracy= 0.99219, Validation Accuracy= 0.96875
# Iteration 1300, Training Accuracy= 0.96875, Validation Accuracy= 0.96875
# Iteration 1400, Training Accuracy= 0.99219, Validation Accuracy= 0.97656
# Iteration 1500, Training Accuracy= 0.97656, Validation Accuracy= 0.98438
# Iteration 1600, Training Accuracy= 0.99219, Validation Accuracy= 0.94531
# Iteration 1700, Training Accuracy= 0.97656, Validation Accuracy= 0.97656
# Iteration 1800, Training Accuracy= 0.99219, Validation Accuracy= 0.96875
# Iteration 1900, Training Accuracy= 0.99219, Validation Accuracy= 0.98438
# Iteration 2000, Training Accuracy= 0.96094, Validation Accuracy= 0.97656
#
#
# Training is finished in 133.0 s !
# Final Training Accuracy: 0.98571
# Final Testing Accuracy:  0.97910

# %% [markdown]
# # Part II. LSTM with Sequence of Pixels

# %%
# define parameters
category = 'LSTM'
learning_rate = 0.001
max_iters = 1000
batch_size = 50
n_input = 1
n_steps = 784
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='C', frequence=1, size=500, show_frequence=50)

# get training accuracy and testing accuracy
model2_train_acc, model2_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model2_train_acc)+1), model2_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model2_cv_acc)+1), model2_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 50, Training Accuracy= 0.13281, Validation Accuracy= 0.15625
# Iteration 100, Training Accuracy= 0.27344, Validation Accuracy= 0.23438
# Iteration 150, Training Accuracy= 0.10156, Validation Accuracy= 0.14844
# Iteration 200, Training Accuracy= 0.15625, Validation Accuracy= 0.07812
# Iteration 250, Training Accuracy= 0.09375, Validation Accuracy= 0.10938
# Iteration 300, Training Accuracy= 0.14844, Validation Accuracy= 0.03906
# Iteration 350, Training Accuracy= 0.08594, Validation Accuracy= 0.13281
# Iteration 400, Training Accuracy= 0.17188, Validation Accuracy= 0.15625
# Iteration 450, Training Accuracy= 0.07812, Validation Accuracy= 0.07031
# Iteration 500, Training Accuracy= 0.21875, Validation Accuracy= 0.14844
# Iteration 550, Training Accuracy= 0.19531, Validation Accuracy= 0.14844
# Iteration 600, Training Accuracy= 0.28906, Validation Accuracy= 0.27344
# Iteration 650, Training Accuracy= 0.14062, Validation Accuracy= 0.12500
# Iteration 700, Training Accuracy= 0.09375, Validation Accuracy= 0.12500
# Iteration 750, Training Accuracy= 0.10156, Validation Accuracy= 0.09375
# Iteration 800, Training Accuracy= 0.10938, Validation Accuracy= 0.12500
# Iteration 850, Training Accuracy= 0.18750, Validation Accuracy= 0.07031
# Iteration 900, Training Accuracy= 0.09375, Validation Accuracy= 0.10156
# Iteration 950, Training Accuracy= 0.11719, Validation Accuracy= 0.10938
# Iteration 1000, Training Accuracy= 0.14062, Validation Accuracy= 0.13281
#
#
# Training is finished in 1747.0 s !
# Final Training Accuracy: 0.11235
# Final Testing Accuracy:  0.11350

# %%
# plot the convergence curve
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))
plt.tight_layout(pad=3.0, h_pad=3.0, w_pad=1.0, rect=None)

ax[0, 0].plot(range(1, len(model1_train_acc)+1), model1_train_acc, 'g-', label='Training Acc')
ax[0, 0].set_title('Basic RNN with 784 steps')
ax[0, 0].set_xlabel('Training Iterations', fontsize=9)
ax[0, 0].set_ylabel('Accuracy')
ax[0, 0].legend(loc='best', fontsize=9)
              
ax[0, 1].plot(range(1, len(model2_train_acc)+1), model2_train_acc, 'c-', label='Training Acc')
ax[0, 1].set_title('LSTM with 784 steps')
ax[0, 1].set_xlabel('Training Iterations', fontsize=9)
# ax[0, 1].set_ylabel('Accuracy')
ax[0, 1].legend(loc='best', fontsize=9)

ax[1, 0].plot(range(1, len(model3_train_acc)+1), model3_train_acc, 'r-', label='Training Acc')
ax[1, 0].set_title('Basic RNN with 28 steps')
ax[1, 0].set_xlabel('Training Iterations', fontsize=9)
ax[1, 0].set_ylabel('Accuracy')
ax[1, 0].legend(loc='best', fontsize=9)

ax[1, 1].plot(range(1, len(model4_train_acc)+1), model4_train_acc, 'y-', label='Training Acc')
ax[1, 1].set_title('LSTM with 28 steps')
ax[1, 1].set_xlabel('Training Iterations', fontsize=9)
# ax[1, 1].set_ylabel('Accuracy')
ax[1, 1].legend(loc='best', fontsize=9)

fig.savefig('./result/convergence_linear_small.pdf')
fig.savefig('./result/convergence_linear_small.png', dpi=300)
plt.show()
