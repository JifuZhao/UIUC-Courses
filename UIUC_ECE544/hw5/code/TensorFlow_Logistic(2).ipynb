# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from RNN2 import RNN

# %matplotlib inline

# load the MNIST dataset
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("data/", one_hot=True)
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# # Part I. Vinalla RNN with Sequence of Pixels

# %%
# define parameters
category = 'basicRNN'
learning_rate = 0.001
max_iters = 2000
batch_size = 128
n_input = 1
n_steps = 784
n_hidden = 100
n_classes = 10
regression = 'logistic'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='C', frequence=1, size=500, show_frequence=100)

# get training accuracy and testing accuracy
model1_train_acc, model1_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model1_train_acc)+1), model1_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model1_cv_acc)+1), model1_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.09000, Validation Accuracy= 0.11400
# Iteration 200, Training Accuracy= 0.11000, Validation Accuracy= 0.09200
# Iteration 300, Training Accuracy= 0.11600, Validation Accuracy= 0.11600
# Iteration 400, Training Accuracy= 0.09800, Validation Accuracy= 0.07400
# Iteration 500, Training Accuracy= 0.11200, Validation Accuracy= 0.10400
# Iteration 600, Training Accuracy= 0.09400, Validation Accuracy= 0.10400
# Iteration 700, Training Accuracy= 0.10200, Validation Accuracy= 0.11000
# Iteration 800, Training Accuracy= 0.14200, Validation Accuracy= 0.09800
# Iteration 900, Training Accuracy= 0.09000, Validation Accuracy= 0.09800
# Iteration 1000, Training Accuracy= 0.08600, Validation Accuracy= 0.08200
# Iteration 1100, Training Accuracy= 0.08200, Validation Accuracy= 0.08800
# Iteration 1200, Training Accuracy= 0.10800, Validation Accuracy= 0.09800
# Iteration 1300, Training Accuracy= 0.09000, Validation Accuracy= 0.07600
# Iteration 1400, Training Accuracy= 0.12200, Validation Accuracy= 0.10400
# Iteration 1500, Training Accuracy= 0.08000, Validation Accuracy= 0.10400
# Iteration 1600, Training Accuracy= 0.06000, Validation Accuracy= 0.09800
# Iteration 1700, Training Accuracy= 0.11600, Validation Accuracy= 0.09400
# Iteration 1800, Training Accuracy= 0.08800, Validation Accuracy= 0.09800
# Iteration 1900, Training Accuracy= 0.09000, Validation Accuracy= 0.10000
# Iteration 2000, Training Accuracy= 0.09600, Validation Accuracy= 0.10600
#
#
# Training is finished in 10545.0 s !
# Final Training Accuracy: 0.10251
# Final Testing Accuracy:  0.10100

# %% [markdown]
# # Part II. LSTM with Sequence of Pixels

# %%
# define parameters
category = 'LSTM'
learning_rate = 0.001
max_iters = 1000
batch_size = 128
n_input = 1
n_steps = 784
n_hidden = 100
n_classes = 10
regression = 'logistic'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='C', frequence=1, size=500, show_frequence=50)

# get training accuracy and testing accuracy
model2_train_acc, model2_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model2_train_acc)+1), model2_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model2_cv_acc)+1), model2_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 50, Training Accuracy= 0.10800, Validation Accuracy= 0.08400
# Iteration 100, Training Accuracy= 0.07000, Validation Accuracy= 0.11400
# Iteration 150, Training Accuracy= 0.11600, Validation Accuracy= 0.09600
# Iteration 200, Training Accuracy= 0.06400, Validation Accuracy= 0.11000
# Iteration 250, Training Accuracy= 0.08400, Validation Accuracy= 0.08200
# Iteration 300, Training Accuracy= 0.11200, Validation Accuracy= 0.09400
# Iteration 350, Training Accuracy= 0.10800, Validation Accuracy= 0.08800
# Iteration 400, Training Accuracy= 0.12000, Validation Accuracy= 0.10400
# Iteration 450, Training Accuracy= 0.09800, Validation Accuracy= 0.09200
# Iteration 500, Training Accuracy= 0.09200, Validation Accuracy= 0.08600
# Iteration 550, Training Accuracy= 0.09400, Validation Accuracy= 0.11600
# Iteration 600, Training Accuracy= 0.09400, Validation Accuracy= 0.09600
# Iteration 650, Training Accuracy= 0.10400, Validation Accuracy= 0.08600
# Iteration 700, Training Accuracy= 0.10400, Validation Accuracy= 0.10200
# Iteration 750, Training Accuracy= 0.10800, Validation Accuracy= 0.09800
# Iteration 800, Training Accuracy= 0.09800, Validation Accuracy= 0.08000
# Iteration 850, Training Accuracy= 0.08800, Validation Accuracy= 0.09800
# Iteration 900, Training Accuracy= 0.10400, Validation Accuracy= 0.12000
# Iteration 950, Training Accuracy= 0.10400, Validation Accuracy= 0.08800
# Iteration 1000, Training Accuracy= 0.11600, Validation Accuracy= 0.09800
#
#
# Training is finished in 11859.0 s !
# Final Training Accuracy: 0.11235
# Final Testing Accuracy:  0.11350

# %% [markdown]
# # Part III. Vinalla RNN with Sequence of Columns

# %%
# define parameters
# 28 steps, inputs is 28 column vector
category = 'basicRNN'
learning_rate = 0.001
max_iters = 2000
batch_size = 128
n_input = 28
n_steps = 28
n_hidden = 100
n_classes = 10
regression = 'logistic'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='F', frequence=1, size=500, show_frequence=100)

# get training accuracy and testing accuracy
model3_train_acc, model3_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model3_train_acc)+1), model3_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model3_cv_acc)+1), model3_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.70800, Validation Accuracy= 0.73400
# Iteration 200, Training Accuracy= 0.82600, Validation Accuracy= 0.81800
# Iteration 300, Training Accuracy= 0.87000, Validation Accuracy= 0.87400
# Iteration 400, Training Accuracy= 0.86600, Validation Accuracy= 0.84600
# Iteration 500, Training Accuracy= 0.85800, Validation Accuracy= 0.88000
# Iteration 600, Training Accuracy= 0.89200, Validation Accuracy= 0.89800
# Iteration 700, Training Accuracy= 0.87400, Validation Accuracy= 0.89600
# Iteration 800, Training Accuracy= 0.89000, Validation Accuracy= 0.88600
# Iteration 900, Training Accuracy= 0.89600, Validation Accuracy= 0.89600
# Iteration 1000, Training Accuracy= 0.90200, Validation Accuracy= 0.90400
# Iteration 1100, Training Accuracy= 0.89600, Validation Accuracy= 0.92400
# Iteration 1200, Training Accuracy= 0.92000, Validation Accuracy= 0.92200
# Iteration 1300, Training Accuracy= 0.90600, Validation Accuracy= 0.90800
# Iteration 1400, Training Accuracy= 0.86800, Validation Accuracy= 0.87000
# Iteration 1500, Training Accuracy= 0.86600, Validation Accuracy= 0.91200
# Iteration 1600, Training Accuracy= 0.91600, Validation Accuracy= 0.88400
# Iteration 1700, Training Accuracy= 0.92200, Validation Accuracy= 0.91200
# Iteration 1800, Training Accuracy= 0.93200, Validation Accuracy= 0.92000
# Iteration 1900, Training Accuracy= 0.93400, Validation Accuracy= 0.91000
# Iteration 2000, Training Accuracy= 0.95000, Validation Accuracy= 0.93200
#
#
# Training is finished in 350.0 s !
# Final Training Accuracy: 0.93464
# Final Testing Accuracy:  0.93480

# %% [markdown]
# # Part IV. LSTM with Sequence of Columns

# %%
# define parameters 
# 28 steps, inputs is 28 column vector
category = 'LSTM'
learning_rate = 0.001
max_iters = 2000
batch_size = 128
n_input = 28
n_steps = 28
n_hidden = 100
n_classes = 10
regression = 'logistic'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='F', frequence=1, size=500, show_frequence=100)

# get training accuracy and testing accuracy
model4_train_acc, model4_cv_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model4_train_acc)+1), model4_train_acc, 'g-', label='Training Accuracy')
ax.plot(range(1, len(model4_cv_acc)+1), model4_cv_acc, 'r-', label='Validation Accuracy')
ax.legend(loc=4, fontsize=10)
plt.show()
# Out:
# Iteration 100, Training Accuracy= 0.66400, Validation Accuracy= 0.69200
# Iteration 200, Training Accuracy= 0.66000, Validation Accuracy= 0.66600
# Iteration 300, Training Accuracy= 0.67600, Validation Accuracy= 0.67800
# Iteration 400, Training Accuracy= 0.65200, Validation Accuracy= 0.67200
# Iteration 500, Training Accuracy= 0.72800, Validation Accuracy= 0.75000
# Iteration 600, Training Accuracy= 0.83000, Validation Accuracy= 0.81400
# Iteration 700, Training Accuracy= 0.88200, Validation Accuracy= 0.88600
# Iteration 800, Training Accuracy= 0.92600, Validation Accuracy= 0.93200
# Iteration 900, Training Accuracy= 0.93000, Validation Accuracy= 0.94000
# Iteration 1000, Training Accuracy= 0.92400, Validation Accuracy= 0.94600
# Iteration 1100, Training Accuracy= 0.96200, Validation Accuracy= 0.96000
# Iteration 1200, Training Accuracy= 0.94400, Validation Accuracy= 0.95800
# Iteration 1300, Training Accuracy= 0.95000, Validation Accuracy= 0.95800
# Iteration 1400, Training Accuracy= 0.94400, Validation Accuracy= 0.95400
# Iteration 1500, Training Accuracy= 0.94400, Validation Accuracy= 0.97000
# Iteration 1600, Training Accuracy= 0.96000, Validation Accuracy= 0.97000
# Iteration 1700, Training Accuracy= 0.97000, Validation Accuracy= 0.96400
# Iteration 1800, Training Accuracy= 0.95600, Validation Accuracy= 0.97200
# Iteration 1900, Training Accuracy= 0.96000, Validation Accuracy= 0.96800
# Iteration 2000, Training Accuracy= 0.97200, Validation Accuracy= 0.97400
#
#
# Training is finished in 761.0 s !
# Final Training Accuracy: 0.96796
# Final Testing Accuracy:  0.96560

# %%
# plot the convergence curve
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))
plt.tight_layout(pad=3.0, h_pad=3.0, w_pad=1.0, rect=None)

ax[0, 0].plot(range(1, len(model1_train_acc)+1), model1_train_acc, 'g-', label='Training Acc')
ax[0, 0].set_title('Basic RNN with 784 steps')
ax[0, 0].set_xlabel('Training Iterations', fontsize=9)
ax[0, 0].set_ylabel('Accuracy')
ax[0, 0].legend(loc='best', fontsize=9)
              
ax[0, 1].plot(range(1, len(model2_train_acc)+1), model2_train_acc, 'c-', label='Training Acc')
ax[0, 1].set_title('LSTM with 784 steps')
ax[0, 1].set_xlabel('Training Iterations', fontsize=9)
# ax[0, 1].set_ylabel('Accuracy')
ax[0, 1].legend(loc='best', fontsize=9)

ax[1, 0].plot(range(1, len(model3_train_acc)+1), model3_train_acc, 'r-', label='Training Acc')
ax[1, 0].set_title('Basic RNN with 28 steps')
ax[1, 0].set_xlabel('Training Iterations', fontsize=9)
ax[1, 0].set_ylabel('Accuracy')
ax[1, 0].legend(loc='best', fontsize=9)

ax[1, 1].plot(range(1, len(model4_train_acc)+1), model4_train_acc, 'y-', label='Training Acc')
ax[1, 1].set_title('LSTM with 28 steps')
ax[1, 1].set_xlabel('Training Iterations', fontsize=9)
# ax[1, 1].set_ylabel('Accuracy')
ax[1, 1].legend(loc='best', fontsize=9)

fig.savefig('./result/convergence_logistic(2).pdf')
fig.savefig('./result/convergence_logistic(2).png', dpi=300)
plt.show()
