# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from RNN import RNN

# %matplotlib inline

# load the MNIST dataset
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("data/", one_hot=True)
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# # Part I. Vinalla RNN with Sequence of Pixels

# %%
# define parameters
category = 'basicRNN'
learning_rate = 0.001
max_iters = 1000
batch_size = 128
n_input = 1
n_steps = 784
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='C', frequence=10, size=10000, show_frequence=50)

# get training accuracy and testing accuracy
model1_train_acc, model1_test_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model1_train_acc)+1), model1_train_acc, 'g-', label='Training Acc')
ax.plot(range(1, len(model1_test_acc)+1), model1_test_acc, 'r-', label='Testing Acc')
ax.legend(loc='best', fontsize=10)
plt.show()
# Out:
# Iter 50, Training Accuracy= 0.11270
# Iter 100, Training Accuracy= 0.11270
# Iter 150, Training Accuracy= 0.11270
# Iter 200, Training Accuracy= 0.10430
# Iter 250, Training Accuracy= 0.11270
# Iter 300, Training Accuracy= 0.11270
# Iter 350, Training Accuracy= 0.11270
# Iter 400, Training Accuracy= 0.10430
# Iter 450, Training Accuracy= 0.11270
# Iter 500, Training Accuracy= 0.11270
# Iter 550, Training Accuracy= 0.09740
# Iter 600, Training Accuracy= 0.11270
# Iter 650, Training Accuracy= 0.11270
# Iter 700, Training Accuracy= 0.09700
# Iter 750, Training Accuracy= 0.09910
# Iter 800, Training Accuracy= 0.09740
# Iter 850, Training Accuracy= 0.09700
# Iter 900, Training Accuracy= 0.11270
# Iter 950, Training Accuracy= 0.11270
# Training is finished in 1637.0 s !
# Final Training Accuracy:	 0.1127
# Final Testing Accuracy:	 0.1135

# %% [markdown]
# # Part II. LSTM with Sequence of Pixels

# %%
# define parameters
category = 'LSTM'
learning_rate = 0.001
max_iters = 1000
batch_size = 128
n_input = 1
n_steps = 784
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='C', frequence=10, size=10000, show_frequence=50)

# get training accuracy and testing accuracy
model2_train_acc, model2_test_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model1_train_acc)+1), model2_train_acc, 'g-', label='Training Acc')
ax.plot(range(1, len(model1_test_acc)+1), model2_test_acc, 'r-', label='Testing Acc')
ax.legend(loc='best', fontsize=10)
plt.show()
# Out:
# Iter 50, Training Accuracy= 0.09320
# Iter 100, Training Accuracy= 0.11130
# Iter 150, Training Accuracy= 0.11130
# Iter 200, Training Accuracy= 0.15720
# Iter 250, Training Accuracy= 0.10290
# Iter 300, Training Accuracy= 0.19210
# Iter 350, Training Accuracy= 0.19010
# Iter 400, Training Accuracy= 0.20780
# Iter 450, Training Accuracy= 0.22040
# Iter 500, Training Accuracy= 0.24910
# Iter 550, Training Accuracy= 0.20940
# Iter 600, Training Accuracy= 0.10290
# Iter 650, Training Accuracy= 0.10290
# Iter 700, Training Accuracy= 0.10290

# %% [markdown]
# # Part III. Vinalla RNN with Sequence of Columns

# %%
# define parameters
# 28 steps, inputs is 28 column vector
category = 'basicRNN'
learning_rate = 0.001
max_iters = 1000
batch_size = 128
n_input = 28
n_steps = 28
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='F', frequence=10, size=10000, show_frequence=50)

# get training accuracy and testing accuracy
model1_train_acc, model1_test_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model1_train_acc)+1), model1_train_acc, 'g-', label='Training Acc')
ax.plot(range(1, len(model1_test_acc)+1), model1_test_acc, 'r-', label='Testing Acc')
ax.legend(loc='best', fontsize=10)
plt.show()

# %% [markdown]
# # Part IV. LSTM with Sequence of Columns

# %%
# define parameters 
# 28 steps, inputs is 28 column vector
category = 'LSTM'
learning_rate = 0.001
max_iters = 1000
batch_size = 128
n_input = 28
n_steps = 28
n_hidden = 100
n_classes = 10
regression = 'linear'

# build the model
model = RNN(category, learning_rate, max_iters, batch_size, 
            n_input, n_steps, n_hidden, n_classes, regression)

# begin training
model.train(mnist, order='F', frequence=10, size=10000, show_frequence=50)

# get training accuracy and testing accuracy
model2_train_acc, model2_test_acc = model.get_params()

# plot the training and testing curve
fig, ax = plt.subplots()
ax.plot(range(1, len(model1_train_acc)+1), model2_train_acc, 'g-', label='Training Acc')
ax.plot(range(1, len(model1_test_acc)+1), model2_test_acc, 'r-', label='Testing Acc')
ax.legend(loc='best', fontsize=10)
plt.show()
