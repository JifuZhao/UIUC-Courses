# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import copy

import tensorflow as tf
from tensorflow.contrib.factorization.python.ops.gmm import GMM
from tensorflow.contrib.factorization.python.ops.kmeans import KMeansClustering as KMeans

# %matplotlib inline

# %%
# read the image
img = plt.imread('./corgi.png')[:, :, :3]

# reshape the input vector
x = np.reshape(img, (-1, 3))
x = x / np.max(x)

# %% [markdown]
# ## 3 clusters

# %%
# train the GMM model
m = 3
gmm = GMM(num_clusters=m, initial_clusters='random', covariance_type='full', verbose=False)
gmm.fit(x)
label = gmm.predict(x)[0, :] + 1

# plot the clustered data
# %matplotlib qt
fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111, projection='3d')
for i in range(1, m + 1):
    data = x[label == i]
    ax.plot(data[:, 0], data[:, 1], data[:, 2], '.', markersize=0.1, label='Class ' + str(i))
ax.set_xlabel('R')
ax.set_ylabel('G')
ax.set_zlabel('B')
# ax.view_init(30)
# ax.legend()
plt.show()

# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, 4):
    test[label == i] = gmm.clusters()[i - 1, :]

plt.imshow(np.reshape(test, img.shape))
plt.show()
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpv07ht1az
# WARNING:tensorflow:Setting feature info to TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(3)]), is_sparse=False)

# %%
print('Mean:\n', gmm.clusters())
print('\nCovariance:\n', gmm.covariances())
# Out:
# Mean:
#  [[ 0.49436137  0.49257523  0.05600471]
#  [ 0.79980087  0.63184911  0.46012625]
#  [ 0.33601248  0.37123555  0.01717021]]
#
# Covariance:
#  [[[ 0.00990595  0.00265989  0.00264318]
#   [ 0.00265989  0.01032908 -0.00414321]
#   [ 0.00264318 -0.00414321  0.00854544]]
#
#  [[ 0.01239599  0.01301438  0.01613066]
#   [ 0.01301444  0.01752938  0.02129519]
#   [ 0.01613066  0.02129519  0.03117353]]
#
#  [[ 0.03568115  0.03606552 -0.00090421]
#   [ 0.03606553  0.04429479 -0.00196513]
#   [-0.00090421 -0.00196513  0.00208076]]]

# %% [markdown]
# ## 5 Clusters

# %%
# train the GMM model
m = 5
gmm = GMM(num_clusters=m, initial_clusters='random', covariance_type='full', verbose=False)
gmm.fit(x)
label = gmm.predict(x)[0, :] + 1

# plot the clustered data
# %matplotlib qt
fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111, projection='3d')
for i in range(1, m + 1):
    data = x[label == i]
    ax.plot(data[:, 0], data[:, 1], data[:, 2], '.', markersize=0.1, label='Class ' + str(i))
ax.set_xlabel('R')
ax.set_ylabel('G')
ax.set_zlabel('B')
# ax.legend()
plt.show()

# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, 4):
    test[label == i] = gmm.clusters()[i - 1, :]

plt.imshow(np.reshape(test, img.shape))
plt.show()
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp6yfdkeey
# WARNING:tensorflow:Setting feature info to TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(3)]), is_sparse=False)

# %% [markdown]
# ## 10 Clusters

# %%
# train the GMM model
m = 10
gmm = GMM(num_clusters=m, initial_clusters='random', covariance_type='full', verbose=False)
gmm.fit(x)
label = gmm.predict(x)[0, :] + 1

# plot the clustered data
# %matplotlib qt
fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111, projection='3d')
for i in range(1, m + 1):
    data = x[label == i]
    ax.plot(data[:, 0], data[:, 1], data[:, 2], '.', markersize=0.1, label='Class ' + str(i))
ax.set_xlabel('R')
ax.set_ylabel('G')
ax.set_zlabel('B')
# ax.legend()
plt.show()

# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, 4):
    test[label == i] = gmm.clusters()[i - 1, :]

plt.imshow(np.reshape(test, img.shape))
plt.show()
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp40wdrxes
# WARNING:tensorflow:Setting feature info to TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(3)]), is_sparse=False)

# %% [markdown]
# # Self Image

# %%
# read the image
img = plt.imread('./self.jpg') / 255

# reshape the input vector
x = np.reshape(img, (-1, 3))
x = x / np.max(x)

# %%
# train the GMM model
m = 3
gmm = GMM(num_clusters=m, initial_clusters='random', covariance_type='full', verbose=False)
gmm.fit(x)
label = gmm.predict(x)[0, :] + 1

# plot the clustered data
# %matplotlib qt
fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111, projection='3d')
for i in range(1, m + 1):
    data = x[label == i]
    ax.plot(data[:, 0], data[:, 1], data[:, 2], '.', markersize=0.1, label='Class ' + str(i))
ax.set_xlabel('R')
ax.set_ylabel('G')
ax.set_zlabel('B')
# ax.legend()
plt.show()

# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, 4):
    test[label == i] = gmm.clusters()[i - 1, :]

plt.imshow(np.reshape(test, img.shape))
plt.show()
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpfyfnoi_d
# WARNING:tensorflow:Setting feature info to TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(3)]), is_sparse=False)

# %%
print('Mean:\n', gmm.clusters())
print('\nCovariance:\n', gmm.covariances())
# Out:
# Mean:
#  [[ 0.39444193  0.45161274  0.39843529]
#  [ 0.22837202  0.30691057  0.22059909]
#  [ 0.62185955  0.66073829  0.70523417]]
#
# Covariance:
#  [[[ 0.03220801  0.02625929  0.02678753]
#   [ 0.02625929  0.02480994  0.02255294]
#   [ 0.02678752  0.02255294  0.03060517]]
#
#  [[ 0.01690264  0.01604268  0.01076809]
#   [ 0.01604268  0.01884991  0.01101104]
#   [ 0.01076809  0.01101104  0.01367268]]
#
#  [[ 0.03842581  0.02839607  0.01881385]
#   [ 0.02839613  0.02400769  0.01766807]
#   [ 0.01881385  0.01766807  0.02031006]]]

# %%
# train the GMM model
m = 5
gmm = GMM(num_clusters=m, initial_clusters='random', covariance_type='full', verbose=False)
gmm.fit(x)
label = gmm.predict(x)[0, :] + 1

# plot the clustered data
# %matplotlib qt
fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111, projection='3d')
for i in range(1, m + 1):
    data = x[label == i]
    ax.plot(data[:, 0], data[:, 1], data[:, 2], '.', markersize=0.1, label='Class ' + str(i))
ax.set_xlabel('R')
ax.set_ylabel('G')
ax.set_zlabel('B')
# ax.legend()
plt.show()

# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, 4):
    test[label == i] = gmm.clusters()[i - 1, :]

plt.imshow(np.reshape(test, img.shape))
plt.show()
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpwquts5ck
# WARNING:tensorflow:Setting feature info to TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(3)]), is_sparse=False)

# %%
# train the GMM model
m = 10
gmm = GMM(num_clusters=m, initial_clusters='random', covariance_type='full', verbose=False)
gmm.fit(x)
label = gmm.predict(x)[0, :] + 1

# plot the clustered data
# %matplotlib qt
fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111, projection='3d')
for i in range(1, m + 1):
    data = x[label == i]
    ax.plot(data[:, 0], data[:, 1], data[:, 2], '.', markersize=0.1, label='Class ' + str(i))
ax.set_xlabel('R')
ax.set_ylabel('G')
ax.set_zlabel('B')
# ax.legend()
plt.show()

# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, 4):
    test[label == i] = gmm.clusters()[i - 1, :]

plt.imshow(np.reshape(test, img.shape))
plt.show()
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpld5cc68w
# WARNING:tensorflow:Setting feature info to TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(3)]), is_sparse=False)
