# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import copy

import tensorflow as tf
from tensorflow.contrib.factorization.python.ops.gmm import GMM
from tensorflow.contrib.factorization.python.ops.kmeans import KMeansClustering as KMeans

# %matplotlib inline

# %% [markdown]
# # Original Figure

# %%
# read the image
img = plt.imread('./corgi.png')[:, :, :3]

# reshape the input vector
x = np.reshape(img, (-1, 3))
x = x / np.max(x)

# %% [markdown]
# ## 3 clusters

# %%
random_seed = 3
# train the GMM model
m = 3
gmm = GMM(num_clusters=m, random_seed=random_seed, initial_clusters='random', 
          covariance_type='full', verbose=False)
gmm.fit(x)
label = gmm.predict(x)[0, :] + 1

# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, m+1):
    test[label == i] = gmm.clusters()[i - 1, :]

fig = plt.figure()
plt.imshow(np.reshape(test, img.shape))
plt.title('Reconstruction with m = 3')
plt.xticks([])
plt.yticks([])
fig.savefig('./result/corgi_tf_3.png', dpi=300)
plt.show()

print('Weights:\n', gmm.get_variable_value('Variable'))
print('Mean:\n', gmm.clusters())
print('\nCovariance:\n', gmm.covariances())
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpx0cjdt17
# WARNING:tensorflow:Setting feature info to TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(3)]), is_sparse=False)
# Weights:
#  [ 0.26407644  0.23359039  0.50233322]
# Mean:
#  [[ 0.76676005  0.59889263  0.42116582]
#  [ 0.19276749  0.16881111  0.05494354]
#  [ 0.45932797  0.51962137  0.00615201]]
#
# Covariance:
#  [[[ 0.01856376  0.01889092  0.02229953]
#   [ 0.01889092  0.02331568  0.02684823]
#   [ 0.02229953  0.02684823  0.03730094]]
#
#  [[ 0.03293373  0.02596048  0.00882943]
#   [ 0.02596048  0.02638968  0.00610389]
#   [ 0.00882943  0.00610389  0.00556187]]
#
#  [[ 0.010445    0.00437354  0.0002251 ]
#   [ 0.00437351  0.00520094  0.00011709]
#   [ 0.0002251   0.00011709  0.00131752]]]

# %% [markdown]
# ## 5 Clusters

# %%
random_seed = 10
# train the GMM model
m = 5
gmm = GMM(num_clusters=m, random_seed=random_seed, initial_clusters='random', 
          covariance_type='full', verbose=False)
gmm.fit(x)
label = gmm.predict(x)[0, :] + 1

# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, m+1):
    test[label == i] = gmm.clusters()[i - 1, :]

fig = plt.figure()
plt.imshow(np.reshape(test, img.shape))
plt.title('Reconstruction with m = 5')
plt.xticks([])
plt.yticks([])
fig.savefig('./result/corgi_tf_5.png', dpi=300)
plt.show()
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpl2t5n__v
# WARNING:tensorflow:Setting feature info to TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(3)]), is_sparse=False)

# %% [markdown]
# ## 10 Clusters

# %%
random_seed = 2
# train the GMM model
m = 10
gmm = GMM(num_clusters=m, random_seed=random_seed, initial_clusters='random', 
          covariance_type='full', verbose=False)
gmm.fit(x)
label = gmm.predict(x)[0, :] + 1

# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, m+1):
    test[label == i] = gmm.clusters()[i - 1, :]

fig = plt.figure()
plt.imshow(np.reshape(test, img.shape))
plt.title('Reconstruction with m = 10')
plt.xticks([])
plt.yticks([])
fig.savefig('./result/corgi_tf_10.png', dpi=300)
plt.show()
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpdj4ib8x9
# WARNING:tensorflow:Setting feature info to TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(3)]), is_sparse=False)

# %% [markdown]
# # Self Image

# %%
# read the image
img = plt.imread('./self.jpg') / 255

# reshape the input vector
x = np.reshape(img, (-1, 3))
x = x / np.max(x)

# %% [markdown]
# ## 3 Mixtures

# %%
random_seed = 5
# train the GMM model
m = 3
gmm = GMM(num_clusters=m, random_seed=random_seed, initial_clusters='random', 
          covariance_type='full', verbose=False)
gmm.fit(x)
label = gmm.predict(x)[0, :] + 1

# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, m+1):
    test[label == i] = gmm.clusters()[i - 1, :]

fig = plt.figure()
plt.imshow(np.reshape(test, img.shape))
plt.title('Reconstruction with m = 3')
plt.xticks([])
plt.yticks([])
fig.savefig('./result/self_tf_3.png', dpi=300)
plt.show()

print('Weights:\n', gmm.get_variable_value('Variable'))
print('Mean:\n', gmm.clusters())
print('\nCovariance:\n', gmm.covariances())
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpgmorhbvh
# WARNING:tensorflow:Setting feature info to TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(3)]), is_sparse=False)
# Weights:
#  [ 0.36099273  0.20816462  0.43084264]
# Mean:
#  [[ 0.70018762  0.71284711  0.72229326]
#  [ 0.46635601  0.54794836  0.63691646]
#  [ 0.23894235  0.31740934  0.23315838]]
#
# Covariance:
#  [[[ 0.02382438  0.01941043  0.01792961]
#   [ 0.01941043  0.01833404  0.0168398 ]
#   [ 0.01792961  0.0168398   0.02003468]]
#
#  [[ 0.02526194  0.01735348  0.00950688]
#   [ 0.01735348  0.01567097  0.01217216]
#   [ 0.00950688  0.0121721   0.02120884]]
#
#  [[ 0.01769399  0.01662316  0.01140809]
#   [ 0.01662316  0.01925556  0.01151332]
#   [ 0.01140809  0.01151332  0.01467827]]]

# %% [markdown]
# ## 5 Mixtures

# %%
random_seed = 7
# train the GMM model
m = 5
gmm = GMM(num_clusters=m, random_seed=random_seed, initial_clusters='random', 
          covariance_type='full', verbose=False)
gmm.fit(x)
label = gmm.predict(x)[0, :] + 1

# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, m+1):
    test[label == i] = gmm.clusters()[i - 1, :]

fig = plt.figure()
plt.imshow(np.reshape(test, img.shape))
plt.title('Reconstruction with m = 5')
plt.xticks([])
plt.yticks([])
fig.savefig('./result/self_tf_5.png', dpi=300)
plt.show()
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpsp1fed6v
# WARNING:tensorflow:Setting feature info to TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(3)]), is_sparse=False)

# %% [markdown]
# ## 10 Mixtures

# %%
random_seed = 10
# train the GMM model
m = 10
gmm = GMM(num_clusters=m, random_seed=random_seed, initial_clusters='random', 
          covariance_type='full', verbose=False)
gmm.fit(x)
label = gmm.predict(x)[0, :] + 1

# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, m+1):
    test[label == i] = gmm.clusters()[i - 1, :]

fig = plt.figure()
plt.imshow(np.reshape(test, img.shape))
plt.title('Reconstruction with m = 10')
plt.xticks([])
plt.yticks([])
fig.savefig('./result/self_tf_10.png', dpi=300)
plt.show()
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpxiqke90k
# WARNING:tensorflow:Setting feature info to TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(3)]), is_sparse=False)
