# %% [markdown]
# ## Using scikit-learn built-in GMM module

# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import mixture
import copy

# %matplotlib inline

# %%
# read the image
img = plt.imread('./corgi.png')[:, :, :3]

# reshape the input vector
x = np.reshape(img, (-1, 3))
x = x / np.max(x)

# %% [markdown]
# ## 3 mixtures

# %%
m = 3
gmm = mixture.GMM(m, covariance_type='full').fit(x)
label = gmm.predict(x) + 1

print('w:\t', np.round(gmm.weights_, 5))
print('\nmu:\t', np.round(gmm.means_, 5))
print('\nsigma:\t', np.round(gmm.covars_, 5))
# Out:
# w:	 [ 0.33588  0.21872  0.4454 ]
#
# mu:	 [[ 0.75924  0.59866  0.41075]
#  [ 0.15978  0.11972  0.05998]
#  [ 0.44383  0.4998   0.00779]]
#
# sigma:	 [[[ 0.02129  0.02026  0.02334]
#   [ 0.02026  0.02458  0.02731]
#   [ 0.02334  0.02731  0.03723]]
#
#  [[ 0.03074  0.02085  0.01083]
#   [ 0.02085  0.01636  0.00769]
#   [ 0.01083  0.00769  0.00623]]
#
#  [[ 0.01033  0.00566  0.00024]
#   [ 0.00566  0.00692  0.00016]
#   [ 0.00024  0.00016  0.00153]]]

# %%
# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, m+1):
    test[label == i] = gmm.means_[i - 1, :]

plt.imshow(np.reshape(test, img.shape))
plt.show()

# %% [markdown]
# ## 5 mixtures

# %%
m = 5
gmm = mixture.GMM(m, covariance_type='full').fit(x)
label = gmm.predict(x) + 1

# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, m+1):
    test[label == i] = gmm.means_[i - 1, :]

plt.imshow(np.reshape(test, img.shape))
plt.show()

# %% [markdown]
# ## 10 mixtures

# %%
m = 10
gmm = mixture.GMM(m, covariance_type='full').fit(x)
label = gmm.predict(x) + 1

# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, m+1):
    test[label == i] = gmm.means_[i - 1, :]

plt.imshow(np.reshape(test, img.shape))
plt.show()

# %% [markdown]
# ## Self figures

# %%
# read the image
img = plt.imread('./self.jpg') / 255

# reshape the input vector
x = np.reshape(img, (-1, 3))
x = x / np.max(x)

# %%
m = 3
gmm = mixture.GMM(m, covariance_type='full').fit(x)
label = gmm.predict(x) + 1

print('w:\t', np.round(gmm.weights_, 5))
print('\nmu:\t', np.round(gmm.means_, 5))
print('\nsigma:\t', np.round(gmm.covars_, 5))

# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, m+1):
    test[label == i] = gmm.means_[i - 1, :]

plt.imshow(np.reshape(test, img.shape))
plt.show()
# Out:
# w:	 [ 0.43434  0.38627  0.17938]
#
# mu:	 [[ 0.2429   0.32557  0.21865]
#  [ 0.64441  0.659    0.66477]
#  [ 0.44675  0.54605  0.67264]]
#
# sigma:	 [[[ 0.01384  0.01237  0.0105 ]
#   [ 0.01237  0.01456  0.00983]
#   [ 0.0105   0.00983  0.01241]]
#
#  [[ 0.0275   0.02399  0.0243 ]
#   [ 0.02399  0.02377  0.02365]
#   [ 0.0243   0.02365  0.0277 ]]
#
#  [[ 0.03023  0.02496  0.0213 ]
#   [ 0.02496  0.02404  0.02198]
#   [ 0.0213   0.02198  0.02685]]]

# %%
m = 5
gmm = mixture.GMM(m, covariance_type='full').fit(x)
label = gmm.predict(x) + 1

# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, m+1):
    test[label == i] = gmm.means_[i - 1, :]

plt.imshow(np.reshape(test, img.shape))
plt.show()

# %%
m = 10
gmm = mixture.GMM(m, covariance_type='full').fit(x)
label = gmm.predict(x) + 1

# reconstruct the image
test = copy.deepcopy(x)
for i in range(1, m+1):
    test[label == i] = gmm.means_[i - 1, :]

plt.imshow(np.reshape(test, img.shape))
plt.show()
