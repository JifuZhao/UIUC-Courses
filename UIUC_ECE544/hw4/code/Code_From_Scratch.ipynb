# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import matplotlib.pyplot as plt
from mnist import MNIST

from RBM import RBM

# %matplotlib inline

# %%
# load MNIST dataset
mndata = MNIST('./data/')

train_img, train_label = mndata.load_training()
train_img = np.array(train_img)

# test_img, test_label = mndata.load_testing()
# test_img = np.array(test_img)

# transform input data into binary values
data = (train_img > 0).astype(float)

# %% [markdown]
# # Batch Learning

# %%
for n in range(1, 6):
    print('***** Using ' + str(n) + ' Outer Iterations *****')
    # build the Restricted Boltzmann Machine
    model = RBM(hidden_nodes=200, learning_rate=0.01, batch_size=10, n_iter=n, verbose=0)

    model.train(data)
    W, b, c = model.get_params()
    
    # visualize the learned weights
    imgs = np.reshape(W[:200, :], (200, 28, 28))

    fig, ax = plt.subplots(nrows=8, ncols=8)
    for i in range(8):
        for j in range(8):
            ax[i, j].imshow(imgs[i * 8 + j, :, :], cmap=plt.cm.gray_r, interpolation='none')
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].axis('image')

    plt.tight_layout(pad=0, h_pad=0, w_pad=0, rect=None)
    plt.show()
# Out:
# ***** Using 1 Outer Iterations *****
# Reach the 1 th iteration, total time 25.42s !
# ***** Using 2 Outer Iterations *****
# Reach the 2 th iteration, total time 37.06s !
# ***** Using 3 Outer Iterations *****
# Reach the 3 th iteration, total time 57.86s !
# ***** Using 4 Outer Iterations *****
# Reach the 4 th iteration, total time 77.58s !
# ***** Using 5 Outer Iterations *****
# Reach the 5 th iteration, total time 94.16s !

# %%
for n in range(1, 6):
    print('***** Using ' + str(n) + ' Outer Iterations *****')
    # build the Restricted Boltzmann Machine
    model = RBM(hidden_nodes=200, learning_rate=0.1, batch_size=5, n_iter=n, verbose=0)

    model.train(data)
    W, b, c = model.get_params()
    
    # visualize the learned weights
    imgs = np.reshape(W[:200, :], (200, 28, 28))

    fig, ax = plt.subplots(nrows=8, ncols=8)
    for i in range(8):
        for j in range(8):
            ax[i, j].imshow(imgs[i * 8 + j, :, :], cmap=plt.cm.gray_r, interpolation='none')
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].axis('image')

    plt.tight_layout(pad=0, h_pad=0, w_pad=0, rect=None)
    plt.show()
# Out:
# ***** Using 1 Outer Iterations *****
# Reach the 1 th iteration, total time 29.79s !
# ***** Using 2 Outer Iterations *****
# Reach the 2 th iteration, total time 56.01s !
# ***** Using 3 Outer Iterations *****
# Reach the 3 th iteration, total time 89.11s !
# ***** Using 4 Outer Iterations *****
# Reach the 4 th iteration, total time 115.77s !
# ***** Using 5 Outer Iterations *****
# Reach the 5 th iteration, total time 155.77s !

# %% [markdown]
# # Single Case

# %%
for n in range(1, 6):
    print('***** Using ' + str(n) + ' Outer Iterations *****')
    # single batch case
    model = RBM(hidden_nodes=200, learning_rate=0.1, batch_size=1, n_iter=n, verbose=0)

    model.train(data)
    W, b, c = model.get_params()

    # visualize the learned weights
    imgs = np.reshape(W[:200, :], (200, 28, 28))

    fig, ax = plt.subplots(nrows=8, ncols=8)
    for i in range(8):
        for j in range(8):
            ax[i, j].imshow(imgs[i * 8 + j, :, :], cmap=plt.cm.gray_r, interpolation='none')
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].axis('image')

    plt.tight_layout(pad=0, h_pad=0, w_pad=0, rect=None)
    plt.show()
# Out:
# ***** Using 1 Outer Iterations *****
# Reach the 1 th iteration, total time 92.65s !
# ***** Using 2 Outer Iterations *****
# Reach the 2 th iteration, total time 167.05s !
# ***** Using 3 Outer Iterations *****
# Reach the 3 th iteration, total time 215.99s !
# ***** Using 4 Outer Iterations *****
# Reach the 4 th iteration, total time 364.38s !
# ***** Using 5 Outer Iterations *****
# Reach the 5 th iteration, total time 412.58s !
